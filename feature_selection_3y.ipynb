# %%
import os
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from scipy.stats import ttest_ind
from scipy import sparse
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler, MaxAbsScaler
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.metrics import classification_report, roc_auc_score
import xgboost as xgb

# %%
# 1) Load concat features and metadata
data = np.load("./data/doc_features/transcript_componenttext_2012_2_features.npz", allow_pickle=True)

# Xc = data["X_concat"]
Xc = data["X_max"]        # shape (N_docs, 2*D)
tids = data["transcriptids"]  # same order
meta = pd.read_csv("./data/doc_features/transcript_componenttext_2012_2_features_meta.csv")

meta_unique = (
    meta[["transcriptid", "SUESCORE", "label"]]
    .drop_duplicates(subset="transcriptid", keep="first")
    .set_index("transcriptid")
)

# 3) build a mask over tids
mask = np.isin(tids, meta_unique.index)

Xc = Xc[mask]
tids = tids[mask]

# 2) Build labels and mask
meta = meta.assign(label=lambda df: df.SUESCORE.map(lambda s: 1 if s>=0.5 else (0 if s<=-0.5 else np.nan)))
mask = meta.label.notna().values
X_test_all_feat, y_test = Xc[mask], meta.loc[mask, "label"].astype(int).values

# %%
# 1) Load concat features and metadata
data = np.load("./data/doc_features/transcript_componenttext_2012_1_features.npz", allow_pickle=True)

Xc = data["X_max"]        # shape (N_docs, 2*D)
tids = data["transcriptids"]  # same order
meta = pd.read_csv("./data/doc_features/transcript_componenttext_2012_1_features_meta.csv")

meta_unique = (
    meta[["transcriptid", "SUESCORE", "label"]]
    .drop_duplicates(subset="transcriptid", keep="first")
    .set_index("transcriptid")
)

# 3) build a mask over tids
mask = np.isin(tids, meta_unique.index)

Xc = Xc[mask]
tids = tids[mask]

# 2) Build labels and mask
meta = meta.assign(label=lambda df: df.SUESCORE.map(lambda s: 1 if s>=0.5 else (0 if s<=-0.5 else np.nan)))
mask = meta.label.notna().values
X_val_all_feat, y_val = Xc[mask], meta.loc[mask, "label"].astype(int).values

# %%
npz_paths = [
    "./data/doc_features/transcript_componenttext_2010_1_features.npz",
    "./data/doc_features/transcript_componenttext_2010_2_features.npz",
    "./data/doc_features/transcript_componenttext_2011_1_features.npz",
    "./data/doc_features/transcript_componenttext_2011_2_features.npz",
    # "./data/doc_features/transcript_componenttext_2012_1_features.npz",
]

# %%
X_list = []
y_list = []

for npz_path in npz_paths:
 
    base = os.path.splitext(os.path.basename(npz_path))[0]      
    csv_path = os.path.join(
        os.path.dirname(npz_path),
        base + "_meta.csv"                                       
    )


    data = np.load(npz_path, allow_pickle=True)
    # X_concat = data["X_concat"]      # (N_docs, 2*D)
    X_concat = data["X_max"]
    tids = data["transcriptids"]    


    meta = pd.read_csv(csv_path)

    meta_unique = (
        meta[["transcriptid", "SUESCORE", "label"]]
        .drop_duplicates(subset="transcriptid", keep="first")
        .set_index("transcriptid")
    )

    mask_ids = np.isin(tids, meta_unique.index)
    X_filt = X_concat[mask_ids]
    tids_filt = np.array(tids)[mask_ids]


    lab_df = meta.assign(
        label=lambda df: df.SUESCORE.map(
            lambda s: 1 if s >= 0.5 else (0 if s <= -0.5 else np.nan)
        )
    )
    mask_label = lab_df.label.notna().values
    # apply the same mask in the same order as the CSV, so we use .loc on lab_df
    # but first filter lab_df to only those transcriptids in tids_filt
    Xc, y = X_filt[mask_label], meta.loc[mask_label, "label"].astype(int).values
    
    # now align X and y
    # X_final = X_filt[lab_sub.label.notna()]
    # y_final = lab_sub.label.astype(int).values

    # collect
    X_list.append(Xc)
    y_list.append(y)

# 2. concatenate all files together
Xc = np.vstack(X_list)   # shape: (sum_i N_i, 2*D)
y  = np.concatenate(y_list)  # shape: (sum_i N_i,)

print("Combined Xc shape:", Xc.shape)
print("Combined y shape: ", y.shape)
# Out:
# Combined Xc shape: (3561, 16384)
# Combined y shape:  (3561,)

# %%
# forced resampling
idx0 = np.where(y == 0)[0]
idx1 = np.where(y == 1)[0]

n = min(len(idx0), len(idx1))

sel0 = np.random.choice(idx0, size=n, replace=False)
sel1 = np.random.choice(idx1, size=n, replace=False)

sel = np.concatenate([sel0, sel1])
np.random.shuffle(sel)

# slice out your balanced subset
Xc = Xc[sel]
y = y[sel]

print("Balanced X shape:", Xc.shape)
print("Balanced y counts:", np.bincount(y))
# Out:
# Balanced X shape: (2040, 32768)
# Balanced y counts: [1020 1020]

# %%
# meta = meta.assign(label=lambda df: df.SUESCORE.map(lambda s: 1 if s>=0.5 else (0 if s<=-0.5 else np.nan)))
# mask = meta.label.notna().values
# Xc, y = Xc_aligned[mask], meta.loc[mask, "label"].astype(int).values

D2 = Xc.shape[1]
D = D2 // 2
X_pos, X_neg = Xc[y==1], Xc[y==0]
t_stats = np.abs((X_pos.mean(0) - X_neg.mean(0)) /
                 np.sqrt(X_pos.var(0)/len(X_pos) + X_neg.var(0)/len(X_neg)))

ranked_idx = np.argsort(-t_stats)


for rank, idx in enumerate(ranked_idx[:1000], start=1):
    # print(idx)
    part = "mean" if idx < D else "max"
    # print(idx)
    # print(D)
    feat_id = idx if idx < D else idx-D
    t_val   = t_stats[idx]
    print(f"Rank {rank:2d}: {part!r} feature #{feat_id} (t = {t_val:.2f})")
# Out:
# Rank  1: 'max' feature #3081 (t = 8.83)
# Rank  2: 'max' feature #7546 (t = 8.71)
# Rank  3: 'max' feature #3581 (t = 8.57)
# Rank  4: 'max' feature #6700 (t = 8.34)
# Rank  5: 'mean' feature #3585 (t = 8.33)
# Rank  6: 'mean' feature #1881 (t = 8.12)
# Rank  7: 'max' feature #4620 (t = 8.06)
# Rank  8: 'max' feature #7429 (t = 7.78)
# Rank  9: 'max' feature #5353 (t = 7.78)
# Rank 10: 'max' feature #5888 (t = 7.76)
# Rank 11: 'max' feature #5425 (t = 7.68)
# Rank 12: 'mean' feature #2366 (t = 7.65)
# Rank 13: 'max' feature #2867 (t = 7.63)
# Rank 14: 'max' feature #188 (t = 7.52)
# Rank 15: 'mean' feature #1547 (t = 7.45)
# Rank 16: 'mean' feature #1211 (t = 7.22)
# Rank 17: 'max' feature #3929 (t = 7.11)
# Rank 18: 'max' feature #8086 (t = 7.07)
# Rank 19: 'max' feature #4883 (t = 7.04)
# Rank 20: 'mean' feature #5240 (t = 6.95)
# Rank 21: 'mean' feature #2845 (t = 6.94)
# Rank 22: 'max' feature #6893 (t = 6.88)
# Rank 23: 'max' feature #4107 (t = 6.84)
# Rank 24: 'mean' feature #4983 (t = 6.80)
# Rank 25: 'max' feature #4808 (t = 6.79)
# Rank 26: 'max' feature #1963 (t = 6.75)
# Rank 27: 'max' feature #5561 (t = 6.74)
# Rank 28: 'mean' feature #7462 (t = 6.73)
# Rank 29: 'mean' feature #1640 (t = 6.70)
# Rank 30: 'mean' feature #5048 (t = 6.69)
# Rank 31: 'mean' feature #133 (t = 6.69)
# Rank 32: 'mean' feature #6139 (t = 6.66)
# Rank 33: 'mean' feature #1477 (t = 6.66)
# Rank 34: 'max' feature #6386 (t = 6.65)
# Rank 35: 'mean' feature #1174 (t = 6.63)
# Rank 36: 'max' feature #2368 (t = 6.60)
# Rank 37: 'max' feature #6973 (t = 6.54)
# Rank 38: 'max' feature #5928 (t = 6.52)
# Rank 39: 'mean' feature #615 (t = 6.51)
# Rank 40: 'mean' feature #7456 (t = 6.51)
# Rank 41: 'mean' feature #4013 (t = 6.49)
# Rank 42: 'mean' feature #3878 (t = 6.46)
# Rank 43: 'max' feature #3026 (t = 6.43)
# Rank 44: 'max' feature #957 (t = 6.42)
# Rank 45: 'mean' feature #1712 (t = 6.42)
# Rank 46: 'max' feature #7382 (t = 6.42)
# Rank 47: 'max' feature #2445 (t = 6.41)
# Rank 48: 'max' feature #4257 (t = 6.39)
# Rank 49: 'mean' feature #2982 (t = 6.39)
# Rank 50: 'mean' feature #2925 (t = 6.38)
# Rank 51: 'max' feature #1733 (t = 6.37)
# Rank 52: 'mean' feature #7357 (t = 6.37)
# Rank 53: 'mean' feature #6000 (t = 6.35)
# Rank 54: 'mean' feature #4152 (t = 6.32)
# Rank 55: 'max' feature #2857 (t = 6.32)
# Rank 56: 'max' feature #7300 (t = 6.30)
# Rank 57: 'max' feature #2408 (t = 6.27)
# Rank 58: 'max' feature #7570 (t = 6.22)
# Rank 59: 'mean' feature #3758 (t = 6.21)
# Rank 60: 'max' feature #2295 (t = 6.21)
# Rank 61: 'max' feature #4001 (t = 6.20)
# Rank 62: 'mean' feature #7246 (t = 6.17)
# Rank 63: 'max' feature #2518 (t = 6.17)
# Rank 64: 'max' feature #1053 (t = 6.16)
# Rank 65: 'max' feature #1818 (t = 6.15)
# Rank 66: 'max' feature #1773 (t = 6.15)
# Rank 67: 'max' feature #7629 (t = 6.14)
# Rank 68: 'mean' feature #6770 (t = 6.14)
# Rank 69: 'max' feature #4673 (t = 6.12)
# Rank 70: 'mean' feature #1457 (t = 6.10)
# Rank 71: 'mean' feature #3549 (t = 6.07)
# Rank 72: 'mean' feature #1911 (t = 6.07)
# Rank 73: 'max' feature #6508 (t = 6.04)
# Rank 74: 'mean' feature #3874 (t = 6.03)
# Rank 75: 'max' feature #3866 (t = 6.02)
# Rank 76: 'mean' feature #6902 (t = 6.01)
# Rank 77: 'mean' feature #945 (t = 5.99)
# Rank 78: 'mean' feature #2415 (t = 5.98)
# Rank 79: 'max' feature #4445 (t = 5.96)
# Rank 80: 'max' feature #83 (t = 5.94)
# Rank 81: 'max' feature #2501 (t = 5.92)
# Rank 82: 'mean' feature #7788 (t = 5.89)
# Rank 83: 'mean' feature #2488 (t = 5.88)
# Rank 84: 'max' feature #2198 (t = 5.87)
# Rank 85: 'mean' feature #1541 (t = 5.85)
# Rank 86: 'mean' feature #2813 (t = 5.82)
# Rank 87: 'max' feature #3222 (t = 5.82)
# Rank 88: 'max' feature #6652 (t = 5.78)
# Rank 89: 'max' feature #7489 (t = 5.77)
# Rank 90: 'max' feature #6381 (t = 5.76)
# Rank 91: 'max' feature #4717 (t = 5.75)
# Rank 92: 'max' feature #6178 (t = 5.75)
# Rank 93: 'mean' feature #2281 (t = 5.74)
# Rank 94: 'max' feature #5808 (t = 5.73)
# Rank 95: 'max' feature #4158 (t = 5.70)
# Rank 96: 'max' feature #2654 (t = 5.69)
# Rank 97: 'mean' feature #940 (t = 5.69)
# Rank 98: 'mean' feature #2133 (t = 5.69)
# Rank 99: 'mean' feature #5230 (t = 5.67)
# Rank 100: 'max' feature #6007 (t = 5.63)
# Rank 101: 'max' feature #522 (t = 5.63)
# Rank 102: 'max' feature #5997 (t = 5.62)
# Rank 103: 'max' feature #7047 (t = 5.60)
# Rank 104: 'max' feature #4750 (t = 5.60)
# Rank 105: 'mean' feature #6211 (t = 5.60)
# Rank 106: 'max' feature #5110 (t = 5.59)
# Rank 107: 'mean' feature #2542 (t = 5.57)
# Rank 108: 'mean' feature #5231 (t = 5.56)
# Rank 109: 'mean' feature #4730 (t = 5.56)
# Rank 110: 'mean' feature #2319 (t = 5.55)
# Rank 111: 'max' feature #29 (t = 5.53)
# Rank 112: 'mean' feature #6370 (t = 5.52)
# Rank 113: 'max' feature #7604 (t = 5.51)
# Rank 114: 'max' feature #4819 (t = 5.50)
# Rank 115: 'max' feature #3386 (t = 5.48)
# Rank 116: 'max' feature #4543 (t = 5.47)
# Rank 117: 'max' feature #219 (t = 5.45)
# Rank 118: 'mean' feature #4789 (t = 5.43)
# Rank 119: 'max' feature #52 (t = 5.42)
# Rank 120: 'mean' feature #1645 (t = 5.42)
# Rank 121: 'mean' feature #4016 (t = 5.42)
# Rank 122: 'max' feature #2949 (t = 5.38)
# Rank 123: 'max' feature #76 (t = 5.37)
# Rank 124: 'mean' feature #5486 (t = 5.37)
# Rank 125: 'mean' feature #585 (t = 5.35)
# Rank 126: 'mean' feature #1700 (t = 5.35)
# Rank 127: 'mean' feature #3749 (t = 5.34)
# Rank 128: 'max' feature #970 (t = 5.34)
# Rank 129: 'mean' feature #7977 (t = 5.33)
# Rank 130: 'mean' feature #6703 (t = 5.33)
# Rank 131: 'max' feature #4828 (t = 5.33)
# Rank 132: 'max' feature #1310 (t = 5.32)
# Rank 133: 'mean' feature #4283 (t = 5.31)
# Rank 134: 'max' feature #776 (t = 5.29)
# Rank 135: 'max' feature #6238 (t = 5.28)
# Rank 136: 'max' feature #1782 (t = 5.27)
# Rank 137: 'max' feature #1320 (t = 5.26)
# Rank 138: 'mean' feature #7722 (t = 5.26)
# Rank 139: 'mean' feature #5776 (t = 5.25)
# Rank 140: 'max' feature #1641 (t = 5.22)
# Rank 141: 'mean' feature #7097 (t = 5.21)
# Rank 142: 'mean' feature #523 (t = 5.21)
# Rank 143: 'max' feature #4305 (t = 5.20)
# Rank 144: 'mean' feature #255 (t = 5.19)
# Rank 145: 'max' feature #2687 (t = 5.19)
# Rank 146: 'mean' feature #1074 (t = 5.17)
# Rank 147: 'max' feature #351 (t = 5.17)
# Rank 148: 'mean' feature #1380 (t = 5.15)
# Rank 149: 'mean' feature #916 (t = 5.14)
# Rank 150: 'mean' feature #6289 (t = 5.14)
# Rank 151: 'max' feature #8037 (t = 5.14)
# Rank 152: 'mean' feature #1635 (t = 5.14)
# Rank 153: 'max' feature #8087 (t = 5.14)
# Rank 154: 'max' feature #860 (t = 5.14)
# Rank 155: 'mean' feature #1519 (t = 5.13)
# Rank 156: 'max' feature #606 (t = 5.13)
# Rank 157: 'max' feature #4585 (t = 5.13)
# Rank 158: 'max' feature #6418 (t = 5.13)
# Rank 159: 'mean' feature #88 (t = 5.12)
# Rank 160: 'max' feature #5848 (t = 5.11)
# Rank 161: 'max' feature #1787 (t = 5.11)
# Rank 162: 'max' feature #1925 (t = 5.10)
# Rank 163: 'mean' feature #2443 (t = 5.10)
# Rank 164: 'mean' feature #4485 (t = 5.09)
# Rank 165: 'mean' feature #1051 (t = 5.08)
# Rank 166: 'max' feature #7070 (t = 5.07)
# Rank 167: 'max' feature #6836 (t = 5.05)
# Rank 168: 'mean' feature #2628 (t = 5.04)
# Rank 169: 'max' feature #6934 (t = 5.03)
# Rank 170: 'max' feature #244 (t = 5.02)
# Rank 171: 'max' feature #4292 (t = 5.02)
# Rank 172: 'max' feature #7623 (t = 5.02)
# Rank 173: 'max' feature #3087 (t = 5.02)
# Rank 174: 'max' feature #1708 (t = 5.01)
# Rank 175: 'mean' feature #3375 (t = 5.01)
# Rank 176: 'max' feature #7421 (t = 5.01)
# Rank 177: 'mean' feature #3494 (t = 5.00)
# Rank 178: 'max' feature #6550 (t = 5.00)
# Rank 179: 'mean' feature #1016 (t = 5.00)
# Rank 180: 'mean' feature #2274 (t = 4.99)
# Rank 181: 'mean' feature #6570 (t = 4.99)
# Rank 182: 'mean' feature #77 (t = 4.99)
# Rank 183: 'mean' feature #3082 (t = 4.99)
# Rank 184: 'max' feature #4308 (t = 4.98)
# Rank 185: 'max' feature #7249 (t = 4.98)
# Rank 186: 'max' feature #4989 (t = 4.96)
# Rank 187: 'max' feature #6085 (t = 4.96)
# Rank 188: 'max' feature #3939 (t = 4.96)
# Rank 189: 'mean' feature #635 (t = 4.95)
# Rank 190: 'mean' feature #2440 (t = 4.95)
# Rank 191: 'max' feature #2111 (t = 4.94)
# Rank 192: 'max' feature #5131 (t = 4.94)
# Rank 193: 'max' feature #4707 (t = 4.94)
# Rank 194: 'max' feature #3449 (t = 4.93)
# Rank 195: 'max' feature #7830 (t = 4.93)
# Rank 196: 'mean' feature #7459 (t = 4.90)
# Rank 197: 'max' feature #342 (t = 4.89)
# Rank 198: 'mean' feature #939 (t = 4.89)
# Rank 199: 'mean' feature #8097 (t = 4.88)
# Rank 200: 'mean' feature #3304 (t = 4.88)
# Rank 201: 'mean' feature #7589 (t = 4.88)
# Rank 202: 'mean' feature #6332 (t = 4.88)
# Rank 203: 'max' feature #7714 (t = 4.88)
# Rank 204: 'mean' feature #1038 (t = 4.87)
# Rank 205: 'max' feature #7891 (t = 4.87)
# Rank 206: 'mean' feature #1446 (t = 4.86)
# Rank 207: 'max' feature #5755 (t = 4.85)
# Rank 208: 'max' feature #7586 (t = 4.84)
# Rank 209: 'max' feature #2213 (t = 4.84)
# Rank 210: 'mean' feature #6237 (t = 4.83)
# Rank 211: 'max' feature #3532 (t = 4.83)
# Rank 212: 'mean' feature #294 (t = 4.83)
# Rank 213: 'max' feature #2225 (t = 4.83)
# Rank 214: 'max' feature #6813 (t = 4.82)
# Rank 215: 'max' feature #6157 (t = 4.82)
# Rank 216: 'mean' feature #4221 (t = 4.81)
# Rank 217: 'mean' feature #4766 (t = 4.81)
# Rank 218: 'mean' feature #2442 (t = 4.81)
# Rank 219: 'mean' feature #6889 (t = 4.79)
# Rank 220: 'mean' feature #4600 (t = 4.79)
# Rank 221: 'mean' feature #4195 (t = 4.79)
# Rank 222: 'max' feature #5302 (t = 4.78)
# Rank 223: 'max' feature #16 (t = 4.78)
# Rank 224: 'max' feature #3070 (t = 4.77)
# Rank 225: 'max' feature #7870 (t = 4.77)
# Rank 226: 'max' feature #3445 (t = 4.76)
# Rank 227: 'max' feature #5163 (t = 4.75)
# Rank 228: 'mean' feature #6058 (t = 4.75)
# Rank 229: 'mean' feature #4060 (t = 4.74)
# Rank 230: 'mean' feature #5629 (t = 4.74)
# Rank 231: 'max' feature #2083 (t = 4.74)
# Rank 232: 'max' feature #5655 (t = 4.74)
# Rank 233: 'mean' feature #5708 (t = 4.73)
# Rank 234: 'mean' feature #7302 (t = 4.73)
# Rank 235: 'max' feature #847 (t = 4.72)
# Rank 236: 'mean' feature #4023 (t = 4.72)
# Rank 237: 'mean' feature #3604 (t = 4.72)
# Rank 238: 'max' feature #5465 (t = 4.72)
# Rank 239: 'max' feature #4471 (t = 4.70)
# Rank 240: 'mean' feature #1562 (t = 4.70)
# Rank 241: 'mean' feature #2310 (t = 4.70)
# Rank 242: 'max' feature #3828 (t = 4.69)
# Rank 243: 'mean' feature #1092 (t = 4.68)
# Rank 244: 'mean' feature #2625 (t = 4.68)
# Rank 245: 'max' feature #3246 (t = 4.68)
# Rank 246: 'max' feature #4848 (t = 4.67)
# Rank 247: 'max' feature #4966 (t = 4.66)
# Rank 248: 'mean' feature #4307 (t = 4.66)
# Rank 249: 'mean' feature #6654 (t = 4.66)
# Rank 250: 'max' feature #3360 (t = 4.66)
# Rank 251: 'max' feature #7467 (t = 4.65)
# Rank 252: 'mean' feature #102 (t = 4.65)
# Rank 253: 'max' feature #3256 (t = 4.65)
# Rank 254: 'max' feature #1916 (t = 4.65)
# Rank 255: 'max' feature #1329 (t = 4.65)
# Rank 256: 'max' feature #1419 (t = 4.64)
# Rank 257: 'max' feature #4117 (t = 4.64)
# Rank 258: 'max' feature #1096 (t = 4.64)
# Rank 259: 'max' feature #5780 (t = 4.64)
# Rank 260: 'max' feature #7218 (t = 4.62)
# Rank 261: 'mean' feature #4075 (t = 4.62)
# Rank 262: 'mean' feature #110 (t = 4.62)
# Rank 263: 'max' feature #2790 (t = 4.62)
# Rank 264: 'mean' feature #3624 (t = 4.61)
# Rank 265: 'max' feature #4315 (t = 4.60)
# Rank 266: 'max' feature #2487 (t = 4.60)
# Rank 267: 'mean' feature #5142 (t = 4.60)
# Rank 268: 'mean' feature #7797 (t = 4.59)
# Rank 269: 'mean' feature #2775 (t = 4.59)
# Rank 270: 'mean' feature #2107 (t = 4.59)
# Rank 271: 'max' feature #5982 (t = 4.58)
# Rank 272: 'max' feature #4670 (t = 4.58)
# Rank 273: 'mean' feature #1390 (t = 4.58)
# Rank 274: 'max' feature #5969 (t = 4.58)
# Rank 275: 'mean' feature #720 (t = 4.57)
# Rank 276: 'max' feature #8139 (t = 4.57)
# Rank 277: 'max' feature #220 (t = 4.57)
# Rank 278: 'max' feature #5162 (t = 4.57)
# Rank 279: 'max' feature #5592 (t = 4.56)
# Rank 280: 'mean' feature #2340 (t = 4.56)
# Rank 281: 'max' feature #3641 (t = 4.56)
# Rank 282: 'max' feature #4384 (t = 4.56)
# Rank 283: 'max' feature #4194 (t = 4.56)
# Rank 284: 'mean' feature #416 (t = 4.56)
# Rank 285: 'max' feature #2001 (t = 4.56)
# Rank 286: 'max' feature #7691 (t = 4.55)
# Rank 287: 'max' feature #4222 (t = 4.55)
# Rank 288: 'mean' feature #3625 (t = 4.55)
# Rank 289: 'max' feature #3032 (t = 4.55)
# Rank 290: 'mean' feature #5485 (t = 4.55)
# Rank 291: 'mean' feature #5752 (t = 4.54)
# Rank 292: 'max' feature #224 (t = 4.53)
# Rank 293: 'mean' feature #3101 (t = 4.53)
# Rank 294: 'max' feature #5590 (t = 4.53)
# Rank 295: 'max' feature #2541 (t = 4.53)
# Rank 296: 'mean' feature #7093 (t = 4.53)
# Rank 297: 'mean' feature #1406 (t = 4.53)
# Rank 298: 'mean' feature #2903 (t = 4.53)
# Rank 299: 'max' feature #1412 (t = 4.52)
# Rank 300: 'mean' feature #7112 (t = 4.52)
# Rank 301: 'max' feature #5066 (t = 4.51)
# Rank 302: 'max' feature #2872 (t = 4.51)
# Rank 303: 'max' feature #6802 (t = 4.51)
# Rank 304: 'mean' feature #1904 (t = 4.51)
# Rank 305: 'max' feature #5363 (t = 4.51)
# Rank 306: 'mean' feature #4177 (t = 4.51)
# Rank 307: 'max' feature #378 (t = 4.51)
# Rank 308: 'max' feature #7786 (t = 4.50)
# Rank 309: 'max' feature #1494 (t = 4.50)
# Rank 310: 'max' feature #844 (t = 4.50)
# Rank 311: 'mean' feature #4264 (t = 4.50)
# Rank 312: 'mean' feature #6261 (t = 4.50)
# Rank 313: 'max' feature #2195 (t = 4.49)
# Rank 314: 'max' feature #2229 (t = 4.49)
# Rank 315: 'mean' feature #7701 (t = 4.49)
# Rank 316: 'mean' feature #1315 (t = 4.49)
# Rank 317: 'max' feature #7734 (t = 4.48)
# Rank 318: 'mean' feature #5343 (t = 4.48)
# Rank 319: 'mean' feature #3366 (t = 4.48)
# Rank 320: 'mean' feature #257 (t = 4.48)
# Rank 321: 'max' feature #713 (t = 4.47)
# Rank 322: 'max' feature #2886 (t = 4.47)
# Rank 323: 'max' feature #972 (t = 4.47)
# Rank 324: 'mean' feature #6965 (t = 4.47)
# Rank 325: 'mean' feature #3456 (t = 4.46)
# Rank 326: 'mean' feature #4531 (t = 4.46)
# Rank 327: 'max' feature #5493 (t = 4.46)
# Rank 328: 'max' feature #3090 (t = 4.46)
# Rank 329: 'max' feature #540 (t = 4.45)
# Rank 330: 'mean' feature #8022 (t = 4.44)
# Rank 331: 'max' feature #261 (t = 4.44)
# Rank 332: 'max' feature #2580 (t = 4.43)
# Rank 333: 'max' feature #118 (t = 4.43)
# Rank 334: 'mean' feature #4392 (t = 4.43)
# Rank 335: 'max' feature #5129 (t = 4.43)
# Rank 336: 'max' feature #5485 (t = 4.42)
# Rank 337: 'mean' feature #6254 (t = 4.42)
# Rank 338: 'max' feature #7420 (t = 4.42)
# Rank 339: 'mean' feature #4546 (t = 4.42)
# Rank 340: 'mean' feature #7861 (t = 4.41)
# Rank 341: 'mean' feature #4988 (t = 4.41)
# Rank 342: 'max' feature #1644 (t = 4.40)
# Rank 343: 'mean' feature #698 (t = 4.40)
# Rank 344: 'max' feature #2031 (t = 4.40)
# Rank 345: 'mean' feature #4646 (t = 4.40)
# Rank 346: 'mean' feature #540 (t = 4.40)
# Rank 347: 'max' feature #5704 (t = 4.40)
# Rank 348: 'max' feature #5036 (t = 4.40)
# Rank 349: 'max' feature #7819 (t = 4.40)
# Rank 350: 'max' feature #4884 (t = 4.39)
# Rank 351: 'mean' feature #5370 (t = 4.39)
# Rank 352: 'mean' feature #3820 (t = 4.39)
# Rank 353: 'max' feature #7555 (t = 4.39)
# Rank 354: 'max' feature #4036 (t = 4.39)
# Rank 355: 'mean' feature #4798 (t = 4.39)
# Rank 356: 'mean' feature #261 (t = 4.39)
# Rank 357: 'max' feature #1403 (t = 4.39)
# Rank 358: 'mean' feature #5046 (t = 4.38)
# Rank 359: 'max' feature #2305 (t = 4.38)
# Rank 360: 'mean' feature #4668 (t = 4.38)
# Rank 361: 'mean' feature #7522 (t = 4.38)
# Rank 362: 'max' feature #909 (t = 4.37)
# Rank 363: 'max' feature #3823 (t = 4.37)
# Rank 364: 'max' feature #1544 (t = 4.37)
# Rank 365: 'max' feature #3003 (t = 4.37)
# Rank 366: 'max' feature #1722 (t = 4.37)
# Rank 367: 'mean' feature #3789 (t = 4.36)
# Rank 368: 'max' feature #1621 (t = 4.36)
# Rank 369: 'mean' feature #3971 (t = 4.35)
# Rank 370: 'max' feature #5120 (t = 4.35)
# Rank 371: 'mean' feature #4948 (t = 4.35)
# Rank 372: 'max' feature #221 (t = 4.35)
# Rank 373: 'mean' feature #5282 (t = 4.35)
# Rank 374: 'mean' feature #1664 (t = 4.35)
# Rank 375: 'mean' feature #3025 (t = 4.34)
# Rank 376: 'mean' feature #4029 (t = 4.34)
# Rank 377: 'mean' feature #4021 (t = 4.34)
# Rank 378: 'mean' feature #8154 (t = 4.34)
# Rank 379: 'max' feature #1119 (t = 4.34)
# Rank 380: 'max' feature #290 (t = 4.33)
# Rank 381: 'max' feature #2263 (t = 4.33)
# Rank 382: 'mean' feature #3763 (t = 4.32)
# Rank 383: 'max' feature #7591 (t = 4.32)
# Rank 384: 'max' feature #5690 (t = 4.32)
# Rank 385: 'mean' feature #4790 (t = 4.32)
# Rank 386: 'mean' feature #1345 (t = 4.31)
# Rank 387: 'max' feature #7820 (t = 4.31)
# Rank 388: 'mean' feature #1880 (t = 4.31)
# Rank 389: 'max' feature #8012 (t = 4.31)
# Rank 390: 'mean' feature #5090 (t = 4.31)
# Rank 391: 'mean' feature #4688 (t = 4.31)
# Rank 392: 'mean' feature #3578 (t = 4.31)
# Rank 393: 'max' feature #5373 (t = 4.30)
# Rank 394: 'mean' feature #6215 (t = 4.30)
# Rank 395: 'mean' feature #2428 (t = 4.30)
# Rank 396: 'max' feature #4302 (t = 4.30)
# Rank 397: 'max' feature #7892 (t = 4.30)
# Rank 398: 'mean' feature #7685 (t = 4.29)
# Rank 399: 'mean' feature #723 (t = 4.29)
# Rank 400: 'max' feature #109 (t = 4.29)
# Rank 401: 'mean' feature #2445 (t = 4.29)
# Rank 402: 'mean' feature #2439 (t = 4.28)
# Rank 403: 'max' feature #6562 (t = 4.28)
# Rank 404: 'max' feature #5937 (t = 4.28)
# Rank 405: 'mean' feature #5448 (t = 4.28)
# Rank 406: 'max' feature #6416 (t = 4.28)
# Rank 407: 'mean' feature #5793 (t = 4.27)
# Rank 408: 'max' feature #1262 (t = 4.27)
# Rank 409: 'mean' feature #1582 (t = 4.26)
# Rank 410: 'max' feature #903 (t = 4.26)
# Rank 411: 'mean' feature #3036 (t = 4.26)
# Rank 412: 'mean' feature #3218 (t = 4.26)
# Rank 413: 'mean' feature #2616 (t = 4.26)
# Rank 414: 'max' feature #1301 (t = 4.25)
# Rank 415: 'max' feature #5137 (t = 4.25)
# Rank 416: 'max' feature #2700 (t = 4.25)
# Rank 417: 'max' feature #2612 (t = 4.24)
# Rank 418: 'mean' feature #4418 (t = 4.24)
# Rank 419: 'max' feature #7503 (t = 4.24)
# Rank 420: 'mean' feature #4604 (t = 4.23)
# Rank 421: 'mean' feature #6078 (t = 4.23)
# Rank 422: 'mean' feature #4892 (t = 4.23)
# Rank 423: 'max' feature #1918 (t = 4.22)
# Rank 424: 'mean' feature #7121 (t = 4.22)
# Rank 425: 'max' feature #5724 (t = 4.22)
# Rank 426: 'mean' feature #7028 (t = 4.22)
# Rank 427: 'max' feature #1898 (t = 4.21)
# Rank 428: 'mean' feature #2798 (t = 4.21)
# Rank 429: 'mean' feature #6432 (t = 4.20)
# Rank 430: 'max' feature #898 (t = 4.20)
# Rank 431: 'max' feature #2525 (t = 4.20)
# Rank 432: 'max' feature #2904 (t = 4.20)
# Rank 433: 'mean' feature #3053 (t = 4.20)
# Rank 434: 'max' feature #4470 (t = 4.19)
# Rank 435: 'mean' feature #8063 (t = 4.19)
# Rank 436: 'max' feature #5574 (t = 4.19)
# Rank 437: 'max' feature #6021 (t = 4.19)
# Rank 438: 'mean' feature #3102 (t = 4.18)
# Rank 439: 'max' feature #4532 (t = 4.18)
# Rank 440: 'mean' feature #1076 (t = 4.18)
# Rank 441: 'mean' feature #1412 (t = 4.18)
# Rank 442: 'mean' feature #1773 (t = 4.17)
# Rank 443: 'max' feature #4364 (t = 4.17)
# Rank 444: 'mean' feature #4550 (t = 4.17)
# Rank 445: 'max' feature #7956 (t = 4.17)
# Rank 446: 'mean' feature #1443 (t = 4.17)
# Rank 447: 'mean' feature #8030 (t = 4.17)
# Rank 448: 'max' feature #5572 (t = 4.16)
# Rank 449: 'mean' feature #7335 (t = 4.16)
# Rank 450: 'max' feature #511 (t = 4.16)
# Rank 451: 'max' feature #3048 (t = 4.16)
# Rank 452: 'mean' feature #3500 (t = 4.15)
# Rank 453: 'mean' feature #5767 (t = 4.14)
# Rank 454: 'max' feature #4017 (t = 4.14)
# Rank 455: 'mean' feature #3116 (t = 4.13)
# Rank 456: 'mean' feature #3771 (t = 4.13)
# Rank 457: 'max' feature #3553 (t = 4.13)
# Rank 458: 'max' feature #1738 (t = 4.13)
# Rank 459: 'mean' feature #2819 (t = 4.13)
# Rank 460: 'max' feature #4605 (t = 4.12)
# Rank 461: 'mean' feature #6141 (t = 4.12)
# Rank 462: 'max' feature #3670 (t = 4.12)
# Rank 463: 'max' feature #2251 (t = 4.12)
# Rank 464: 'max' feature #7886 (t = 4.12)
# Rank 465: 'mean' feature #4654 (t = 4.11)
# Rank 466: 'max' feature #361 (t = 4.11)
# Rank 467: 'mean' feature #6061 (t = 4.11)
# Rank 468: 'mean' feature #6448 (t = 4.11)
# Rank 469: 'mean' feature #5403 (t = 4.11)
# Rank 470: 'max' feature #3448 (t = 4.10)
# Rank 471: 'max' feature #1286 (t = 4.10)
# Rank 472: 'mean' feature #399 (t = 4.10)
# Rank 473: 'mean' feature #1595 (t = 4.10)
# Rank 474: 'max' feature #1756 (t = 4.10)
# Rank 475: 'max' feature #1005 (t = 4.09)
# Rank 476: 'max' feature #4674 (t = 4.09)
# Rank 477: 'mean' feature #2233 (t = 4.09)
# Rank 478: 'mean' feature #62 (t = 4.09)
# Rank 479: 'max' feature #6346 (t = 4.08)
# Rank 480: 'mean' feature #1023 (t = 4.08)
# Rank 481: 'mean' feature #4842 (t = 4.08)
# Rank 482: 'mean' feature #3524 (t = 4.08)
# Rank 483: 'max' feature #2453 (t = 4.08)
# Rank 484: 'mean' feature #6470 (t = 4.07)
# Rank 485: 'mean' feature #2505 (t = 4.07)
# Rank 486: 'mean' feature #1482 (t = 4.07)
# Rank 487: 'mean' feature #3743 (t = 4.07)
# Rank 488: 'mean' feature #7400 (t = 4.07)
# Rank 489: 'max' feature #8111 (t = 4.07)
# Rank 490: 'mean' feature #1796 (t = 4.07)
# Rank 491: 'max' feature #3863 (t = 4.06)
# Rank 492: 'mean' feature #188 (t = 4.06)
# Rank 493: 'mean' feature #1946 (t = 4.06)
# Rank 494: 'mean' feature #4750 (t = 4.06)
# Rank 495: 'mean' feature #1462 (t = 4.06)
# Rank 496: 'max' feature #5734 (t = 4.06)
# Rank 497: 'mean' feature #629 (t = 4.05)
# Rank 498: 'mean' feature #3481 (t = 4.05)
# Rank 499: 'max' feature #1633 (t = 4.05)
# Rank 500: 'mean' feature #6034 (t = 4.05)
# Rank 501: 'mean' feature #8122 (t = 4.05)
# Rank 502: 'mean' feature #1591 (t = 4.04)
# Rank 503: 'max' feature #141 (t = 4.04)
# Rank 504: 'mean' feature #646 (t = 4.04)
# Rank 505: 'max' feature #3269 (t = 4.04)
# Rank 506: 'max' feature #4676 (t = 4.04)
# Rank 507: 'mean' feature #7215 (t = 4.04)
# Rank 508: 'max' feature #4873 (t = 4.03)
# Rank 509: 'mean' feature #4271 (t = 4.03)
# Rank 510: 'max' feature #4307 (t = 4.03)
# Rank 511: 'mean' feature #6832 (t = 4.03)
# Rank 512: 'max' feature #7465 (t = 4.03)
# Rank 513: 'mean' feature #4824 (t = 4.02)
# Rank 514: 'max' feature #4772 (t = 4.02)
# Rank 515: 'mean' feature #971 (t = 4.02)
# Rank 516: 'mean' feature #1594 (t = 4.02)
# Rank 517: 'mean' feature #4837 (t = 4.01)
# Rank 518: 'mean' feature #1679 (t = 4.01)
# Rank 519: 'max' feature #1026 (t = 4.01)
# Rank 520: 'mean' feature #2889 (t = 4.01)
# Rank 521: 'mean' feature #249 (t = 4.01)
# Rank 522: 'mean' feature #7899 (t = 4.01)
# Rank 523: 'mean' feature #8121 (t = 4.00)
# Rank 524: 'mean' feature #5572 (t = 4.00)
# Rank 525: 'max' feature #3471 (t = 4.00)
# Rank 526: 'max' feature #509 (t = 4.00)
# Rank 527: 'mean' feature #2751 (t = 4.00)
# Rank 528: 'mean' feature #1739 (t = 4.00)
# Rank 529: 'mean' feature #6486 (t = 4.00)
# Rank 530: 'max' feature #3441 (t = 3.99)
# Rank 531: 'max' feature #1464 (t = 3.99)
# Rank 532: 'max' feature #6348 (t = 3.99)
# Rank 533: 'mean' feature #1988 (t = 3.99)
# Rank 534: 'max' feature #948 (t = 3.99)
# Rank 535: 'max' feature #6507 (t = 3.99)
# Rank 536: 'mean' feature #3552 (t = 3.99)
# Rank 537: 'max' feature #1383 (t = 3.99)
# Rank 538: 'mean' feature #5701 (t = 3.99)
# Rank 539: 'max' feature #5820 (t = 3.98)
# Rank 540: 'max' feature #5303 (t = 3.98)
# Rank 541: 'mean' feature #7606 (t = 3.98)
# Rank 542: 'mean' feature #7517 (t = 3.98)
# Rank 543: 'mean' feature #7061 (t = 3.98)
# Rank 544: 'max' feature #1861 (t = 3.97)
# Rank 545: 'max' feature #133 (t = 3.97)
# Rank 546: 'max' feature #3996 (t = 3.97)
# Rank 547: 'mean' feature #4838 (t = 3.97)
# Rank 548: 'max' feature #1819 (t = 3.97)
# Rank 549: 'max' feature #5040 (t = 3.97)
# Rank 550: 'mean' feature #2290 (t = 3.97)
# Rank 551: 'max' feature #4478 (t = 3.96)
# Rank 552: 'mean' feature #6419 (t = 3.96)
# Rank 553: 'max' feature #6783 (t = 3.96)
# Rank 554: 'max' feature #3751 (t = 3.96)
# Rank 555: 'max' feature #8148 (t = 3.96)
# Rank 556: 'max' feature #1921 (t = 3.96)
# Rank 557: 'mean' feature #2007 (t = 3.96)
# Rank 558: 'mean' feature #5143 (t = 3.96)
# Rank 559: 'max' feature #1894 (t = 3.96)
# Rank 560: 'mean' feature #3207 (t = 3.96)
# Rank 561: 'max' feature #8182 (t = 3.96)
# Rank 562: 'mean' feature #7496 (t = 3.95)
# Rank 563: 'max' feature #7534 (t = 3.95)
# Rank 564: 'mean' feature #6155 (t = 3.95)
# Rank 565: 'mean' feature #4372 (t = 3.95)
# Rank 566: 'max' feature #2095 (t = 3.95)
# Rank 567: 'mean' feature #2811 (t = 3.95)
# Rank 568: 'max' feature #6363 (t = 3.95)
# Rank 569: 'max' feature #5632 (t = 3.95)
# Rank 570: 'mean' feature #6355 (t = 3.95)
# Rank 571: 'max' feature #2357 (t = 3.95)
# Rank 572: 'mean' feature #6368 (t = 3.94)
# Rank 573: 'max' feature #1999 (t = 3.94)
# Rank 574: 'mean' feature #6389 (t = 3.94)
# Rank 575: 'mean' feature #6325 (t = 3.94)
# Rank 576: 'max' feature #3105 (t = 3.94)
# Rank 577: 'mean' feature #6869 (t = 3.94)
# Rank 578: 'mean' feature #5103 (t = 3.94)
# Rank 579: 'mean' feature #5290 (t = 3.94)
# Rank 580: 'max' feature #6420 (t = 3.93)
# Rank 581: 'mean' feature #3328 (t = 3.93)
# Rank 582: 'max' feature #2592 (t = 3.93)
# Rank 583: 'max' feature #6464 (t = 3.93)
# Rank 584: 'max' feature #1003 (t = 3.93)
# Rank 585: 'mean' feature #7245 (t = 3.93)
# Rank 586: 'mean' feature #5697 (t = 3.93)
# Rank 587: 'mean' feature #112 (t = 3.92)
# Rank 588: 'max' feature #6603 (t = 3.92)
# Rank 589: 'mean' feature #1162 (t = 3.92)
# Rank 590: 'max' feature #2153 (t = 3.92)
# Rank 591: 'max' feature #6556 (t = 3.92)
# Rank 592: 'mean' feature #697 (t = 3.92)
# Rank 593: 'mean' feature #3562 (t = 3.92)
# Rank 594: 'mean' feature #3254 (t = 3.92)
# Rank 595: 'max' feature #6716 (t = 3.91)
# Rank 596: 'mean' feature #5498 (t = 3.91)
# Rank 597: 'max' feature #3829 (t = 3.91)
# Rank 598: 'mean' feature #4547 (t = 3.91)
# Rank 599: 'max' feature #7735 (t = 3.91)
# Rank 600: 'max' feature #6314 (t = 3.91)
# Rank 601: 'mean' feature #3970 (t = 3.91)
# Rank 602: 'mean' feature #4502 (t = 3.90)
# Rank 603: 'mean' feature #1078 (t = 3.90)
# Rank 604: 'mean' feature #3289 (t = 3.90)
# Rank 605: 'mean' feature #1975 (t = 3.90)
# Rank 606: 'max' feature #3020 (t = 3.90)
# Rank 607: 'max' feature #3848 (t = 3.90)
# Rank 608: 'mean' feature #473 (t = 3.90)
# Rank 609: 'max' feature #155 (t = 3.90)
# Rank 610: 'max' feature #5148 (t = 3.89)
# Rank 611: 'mean' feature #1432 (t = 3.89)
# Rank 612: 'mean' feature #5672 (t = 3.89)
# Rank 613: 'mean' feature #1415 (t = 3.89)
# Rank 614: 'mean' feature #3317 (t = 3.89)
# Rank 615: 'max' feature #2014 (t = 3.89)
# Rank 616: 'max' feature #4281 (t = 3.89)
# Rank 617: 'mean' feature #3155 (t = 3.89)
# Rank 618: 'mean' feature #672 (t = 3.89)
# Rank 619: 'max' feature #3962 (t = 3.89)
# Rank 620: 'max' feature #2290 (t = 3.89)
# Rank 621: 'max' feature #4000 (t = 3.89)
# Rank 622: 'max' feature #7656 (t = 3.88)
# Rank 623: 'mean' feature #8113 (t = 3.88)
# Rank 624: 'mean' feature #6627 (t = 3.88)
# Rank 625: 'mean' feature #4979 (t = 3.88)
# Rank 626: 'mean' feature #3922 (t = 3.88)
# Rank 627: 'mean' feature #1516 (t = 3.88)
# Rank 628: 'max' feature #2180 (t = 3.88)
# Rank 629: 'max' feature #6095 (t = 3.88)
# Rank 630: 'mean' feature #4007 (t = 3.87)
# Rank 631: 'max' feature #6471 (t = 3.87)
# Rank 632: 'mean' feature #3697 (t = 3.87)
# Rank 633: 'mean' feature #1518 (t = 3.87)
# Rank 634: 'max' feature #5930 (t = 3.87)
# Rank 635: 'max' feature #5203 (t = 3.87)
# Rank 636: 'mean' feature #6785 (t = 3.87)
# Rank 637: 'mean' feature #2004 (t = 3.87)
# Rank 638: 'max' feature #1150 (t = 3.87)
# Rank 639: 'max' feature #2953 (t = 3.87)
# Rank 640: 'max' feature #5822 (t = 3.87)
# Rank 641: 'max' feature #4734 (t = 3.86)
# Rank 642: 'max' feature #3410 (t = 3.86)
# Rank 643: 'mean' feature #8124 (t = 3.86)
# Rank 644: 'mean' feature #5289 (t = 3.86)
# Rank 645: 'mean' feature #4655 (t = 3.86)
# Rank 646: 'max' feature #7346 (t = 3.86)
# Rank 647: 'mean' feature #5284 (t = 3.86)
# Rank 648: 'max' feature #2597 (t = 3.86)
# Rank 649: 'max' feature #4403 (t = 3.85)
# Rank 650: 'mean' feature #6802 (t = 3.85)
# Rank 651: 'max' feature #3557 (t = 3.85)
# Rank 652: 'max' feature #5088 (t = 3.85)
# Rank 653: 'mean' feature #1250 (t = 3.85)
# Rank 654: 'max' feature #6824 (t = 3.84)
# Rank 655: 'mean' feature #2570 (t = 3.84)
# Rank 656: 'max' feature #7822 (t = 3.84)
# Rank 657: 'max' feature #5181 (t = 3.84)
# Rank 658: 'mean' feature #32 (t = 3.84)
# Rank 659: 'mean' feature #7324 (t = 3.84)
# Rank 660: 'max' feature #819 (t = 3.84)
# Rank 661: 'max' feature #4455 (t = 3.84)
# Rank 662: 'mean' feature #7679 (t = 3.84)
# Rank 663: 'mean' feature #3990 (t = 3.83)
# Rank 664: 'max' feature #5243 (t = 3.83)
# Rank 665: 'mean' feature #6182 (t = 3.83)
# Rank 666: 'mean' feature #4538 (t = 3.83)
# Rank 667: 'max' feature #7336 (t = 3.83)
# Rank 668: 'mean' feature #3230 (t = 3.83)
# Rank 669: 'mean' feature #6556 (t = 3.83)
# Rank 670: 'mean' feature #7565 (t = 3.83)
# Rank 671: 'mean' feature #7886 (t = 3.83)
# Rank 672: 'max' feature #2479 (t = 3.83)
# Rank 673: 'max' feature #6004 (t = 3.82)
# Rank 674: 'max' feature #2065 (t = 3.82)
# Rank 675: 'max' feature #1404 (t = 3.82)
# Rank 676: 'mean' feature #753 (t = 3.82)
# Rank 677: 'mean' feature #1281 (t = 3.82)
# Rank 678: 'mean' feature #8025 (t = 3.81)
# Rank 679: 'max' feature #2915 (t = 3.81)
# Rank 680: 'max' feature #3151 (t = 3.81)
# Rank 681: 'mean' feature #7993 (t = 3.81)
# Rank 682: 'mean' feature #4944 (t = 3.81)
# Rank 683: 'max' feature #7160 (t = 3.81)
# Rank 684: 'max' feature #3086 (t = 3.81)
# Rank 685: 'max' feature #2391 (t = 3.81)
# Rank 686: 'max' feature #5015 (t = 3.81)
# Rank 687: 'mean' feature #5404 (t = 3.81)
# Rank 688: 'max' feature #1126 (t = 3.81)
# Rank 689: 'max' feature #7260 (t = 3.81)
# Rank 690: 'mean' feature #5120 (t = 3.81)
# Rank 691: 'mean' feature #2525 (t = 3.81)
# Rank 692: 'max' feature #2560 (t = 3.81)
# Rank 693: 'mean' feature #6266 (t = 3.80)
# Rank 694: 'mean' feature #3987 (t = 3.80)
# Rank 695: 'max' feature #2074 (t = 3.80)
# Rank 696: 'mean' feature #721 (t = 3.80)
# Rank 697: 'mean' feature #4465 (t = 3.80)
# Rank 698: 'max' feature #7320 (t = 3.80)
# Rank 699: 'max' feature #5945 (t = 3.80)
# Rank 700: 'max' feature #1929 (t = 3.80)
# Rank 701: 'max' feature #7759 (t = 3.80)
# Rank 702: 'max' feature #7704 (t = 3.80)
# Rank 703: 'max' feature #6910 (t = 3.80)
# Rank 704: 'max' feature #969 (t = 3.80)
# Rank 705: 'max' feature #1350 (t = 3.79)
# Rank 706: 'mean' feature #214 (t = 3.79)
# Rank 707: 'mean' feature #6578 (t = 3.79)
# Rank 708: 'max' feature #6819 (t = 3.79)
# Rank 709: 'max' feature #2346 (t = 3.79)
# Rank 710: 'mean' feature #4147 (t = 3.79)
# Rank 711: 'mean' feature #5267 (t = 3.79)
# Rank 712: 'max' feature #5071 (t = 3.78)
# Rank 713: 'max' feature #2528 (t = 3.78)
# Rank 714: 'max' feature #6226 (t = 3.78)
# Rank 715: 'mean' feature #4146 (t = 3.78)
# Rank 716: 'max' feature #1134 (t = 3.78)
# Rank 717: 'max' feature #1737 (t = 3.78)
# Rank 718: 'max' feature #2109 (t = 3.78)
# Rank 719: 'max' feature #5809 (t = 3.78)
# Rank 720: 'mean' feature #490 (t = 3.77)
# Rank 721: 'mean' feature #2627 (t = 3.77)
# Rank 722: 'mean' feature #153 (t = 3.77)
# Rank 723: 'mean' feature #5171 (t = 3.77)
# Rank 724: 'max' feature #4490 (t = 3.77)
# Rank 725: 'mean' feature #1483 (t = 3.77)
# Rank 726: 'mean' feature #6480 (t = 3.77)
# Rank 727: 'mean' feature #2685 (t = 3.77)
# Rank 728: 'mean' feature #3724 (t = 3.76)
# Rank 729: 'mean' feature #909 (t = 3.76)
# Rank 730: 'mean' feature #5092 (t = 3.76)
# Rank 731: 'mean' feature #5982 (t = 3.76)
# Rank 732: 'mean' feature #6428 (t = 3.76)
# Rank 733: 'max' feature #2527 (t = 3.76)
# Rank 734: 'mean' feature #3645 (t = 3.76)
# Rank 735: 'mean' feature #4099 (t = 3.76)
# Rank 736: 'max' feature #3854 (t = 3.76)
# Rank 737: 'mean' feature #4371 (t = 3.75)
# Rank 738: 'max' feature #5506 (t = 3.75)
# Rank 739: 'max' feature #3233 (t = 3.75)
# Rank 740: 'max' feature #310 (t = 3.75)
# Rank 741: 'mean' feature #898 (t = 3.75)
# Rank 742: 'max' feature #1415 (t = 3.75)
# Rank 743: 'max' feature #5703 (t = 3.75)
# Rank 744: 'max' feature #947 (t = 3.75)
# Rank 745: 'mean' feature #1090 (t = 3.75)
# Rank 746: 'max' feature #2934 (t = 3.74)
# Rank 747: 'mean' feature #7528 (t = 3.74)
# Rank 748: 'max' feature #3911 (t = 3.74)
# Rank 749: 'mean' feature #5553 (t = 3.74)
# Rank 750: 'mean' feature #6628 (t = 3.74)
# Rank 751: 'mean' feature #266 (t = 3.74)
# Rank 752: 'mean' feature #2148 (t = 3.74)
# Rank 753: 'max' feature #2410 (t = 3.74)
# Rank 754: 'max' feature #2513 (t = 3.74)
# Rank 755: 'mean' feature #2384 (t = 3.74)
# Rank 756: 'mean' feature #1020 (t = 3.74)
# Rank 757: 'mean' feature #6087 (t = 3.74)
# Rank 758: 'max' feature #771 (t = 3.74)
# Rank 759: 'mean' feature #6156 (t = 3.73)
# Rank 760: 'mean' feature #2593 (t = 3.73)
# Rank 761: 'mean' feature #1179 (t = 3.73)
# Rank 762: 'mean' feature #1256 (t = 3.73)
# Rank 763: 'max' feature #2701 (t = 3.73)
# Rank 764: 'max' feature #7372 (t = 3.73)
# Rank 765: 'mean' feature #5959 (t = 3.73)
# Rank 766: 'mean' feature #5612 (t = 3.73)
# Rank 767: 'max' feature #1252 (t = 3.73)
# Rank 768: 'mean' feature #4571 (t = 3.73)
# Rank 769: 'mean' feature #7452 (t = 3.72)
# Rank 770: 'mean' feature #5162 (t = 3.72)
# Rank 771: 'mean' feature #2946 (t = 3.72)
# Rank 772: 'mean' feature #5855 (t = 3.72)
# Rank 773: 'max' feature #2310 (t = 3.72)
# Rank 774: 'max' feature #1882 (t = 3.72)
# Rank 775: 'max' feature #3583 (t = 3.72)
# Rank 776: 'mean' feature #345 (t = 3.72)
# Rank 777: 'mean' feature #705 (t = 3.72)
# Rank 778: 'mean' feature #7373 (t = 3.71)
# Rank 779: 'max' feature #971 (t = 3.71)
# Rank 780: 'max' feature #7551 (t = 3.71)
# Rank 781: 'max' feature #6697 (t = 3.71)
# Rank 782: 'max' feature #4824 (t = 3.71)
# Rank 783: 'mean' feature #6523 (t = 3.71)
# Rank 784: 'mean' feature #3772 (t = 3.71)
# Rank 785: 'max' feature #6985 (t = 3.71)
# Rank 786: 'max' feature #5266 (t = 3.70)
# Rank 787: 'mean' feature #6359 (t = 3.70)
# Rank 788: 'mean' feature #6361 (t = 3.70)
# Rank 789: 'max' feature #1797 (t = 3.70)
# Rank 790: 'max' feature #4399 (t = 3.70)
# Rank 791: 'mean' feature #6500 (t = 3.70)
# Rank 792: 'max' feature #5765 (t = 3.70)
# Rank 793: 'mean' feature #844 (t = 3.70)
# Rank 794: 'max' feature #7204 (t = 3.69)
# Rank 795: 'max' feature #5756 (t = 3.69)
# Rank 796: 'mean' feature #4408 (t = 3.69)
# Rank 797: 'mean' feature #7198 (t = 3.69)
# Rank 798: 'mean' feature #2893 (t = 3.69)
# Rank 799: 'max' feature #7680 (t = 3.69)
# Rank 800: 'mean' feature #5817 (t = 3.69)
# Rank 801: 'mean' feature #2479 (t = 3.69)
# Rank 802: 'max' feature #6568 (t = 3.69)
# Rank 803: 'mean' feature #353 (t = 3.69)
# Rank 804: 'max' feature #3440 (t = 3.69)
# Rank 805: 'mean' feature #455 (t = 3.69)
# Rank 806: 'max' feature #250 (t = 3.69)
# Rank 807: 'max' feature #6645 (t = 3.68)
# Rank 808: 'mean' feature #4521 (t = 3.68)
# Rank 809: 'max' feature #6038 (t = 3.68)
# Rank 810: 'max' feature #3344 (t = 3.68)
# Rank 811: 'mean' feature #6697 (t = 3.68)
# Rank 812: 'mean' feature #158 (t = 3.68)
# Rank 813: 'mean' feature #1459 (t = 3.68)
# Rank 814: 'max' feature #6283 (t = 3.68)
# Rank 815: 'max' feature #2272 (t = 3.68)
# Rank 816: 'max' feature #1371 (t = 3.68)
# Rank 817: 'max' feature #2373 (t = 3.68)
# Rank 818: 'mean' feature #5746 (t = 3.67)
# Rank 819: 'max' feature #6359 (t = 3.67)
# Rank 820: 'mean' feature #3949 (t = 3.67)
# Rank 821: 'max' feature #7516 (t = 3.67)
# Rank 822: 'max' feature #631 (t = 3.67)
# Rank 823: 'max' feature #7038 (t = 3.67)
# Rank 824: 'max' feature #7846 (t = 3.67)
# Rank 825: 'max' feature #6958 (t = 3.67)
# Rank 826: 'max' feature #6686 (t = 3.67)
# Rank 827: 'mean' feature #7271 (t = 3.67)
# Rank 828: 'max' feature #5153 (t = 3.67)
# Rank 829: 'max' feature #5126 (t = 3.67)
# Rank 830: 'max' feature #6679 (t = 3.66)
# Rank 831: 'mean' feature #7696 (t = 3.66)
# Rank 832: 'mean' feature #7009 (t = 3.66)
# Rank 833: 'mean' feature #3584 (t = 3.66)
# Rank 834: 'mean' feature #106 (t = 3.66)
# Rank 835: 'mean' feature #6709 (t = 3.66)
# Rank 836: 'max' feature #751 (t = 3.66)
# Rank 837: 'max' feature #1615 (t = 3.66)
# Rank 838: 'max' feature #1075 (t = 3.66)
# Rank 839: 'max' feature #4432 (t = 3.66)
# Rank 840: 'max' feature #2451 (t = 3.66)
# Rank 841: 'mean' feature #546 (t = 3.65)
# Rank 842: 'mean' feature #7130 (t = 3.65)
# Rank 843: 'max' feature #4967 (t = 3.65)
# Rank 844: 'mean' feature #5024 (t = 3.65)
# Rank 845: 'mean' feature #2267 (t = 3.65)
# Rank 846: 'mean' feature #6290 (t = 3.65)
# Rank 847: 'mean' feature #6842 (t = 3.65)
# Rank 848: 'max' feature #122 (t = 3.65)
# Rank 849: 'mean' feature #1854 (t = 3.64)
# Rank 850: 'max' feature #1440 (t = 3.64)
# Rank 851: 'max' feature #3692 (t = 3.64)
# Rank 852: 'max' feature #7217 (t = 3.64)
# Rank 853: 'max' feature #926 (t = 3.64)
# Rank 854: 'max' feature #2306 (t = 3.64)
# Rank 855: 'max' feature #3369 (t = 3.64)
# Rank 856: 'max' feature #5112 (t = 3.64)
# Rank 857: 'mean' feature #4543 (t = 3.64)
# Rank 858: 'max' feature #2296 (t = 3.64)
# Rank 859: 'max' feature #3202 (t = 3.64)
# Rank 860: 'mean' feature #3047 (t = 3.64)
# Rank 861: 'max' feature #4872 (t = 3.64)
# Rank 862: 'max' feature #5477 (t = 3.63)
# Rank 863: 'mean' feature #4689 (t = 3.63)
# Rank 864: 'max' feature #2349 (t = 3.63)
# Rank 865: 'max' feature #5771 (t = 3.63)
# Rank 866: 'mean' feature #3937 (t = 3.63)
# Rank 867: 'max' feature #7283 (t = 3.63)
# Rank 868: 'max' feature #4765 (t = 3.63)
# Rank 869: 'mean' feature #6203 (t = 3.63)
# Rank 870: 'mean' feature #671 (t = 3.62)
# Rank 871: 'max' feature #4856 (t = 3.62)
# Rank 872: 'mean' feature #5078 (t = 3.62)
# Rank 873: 'mean' feature #7550 (t = 3.62)
# Rank 874: 'max' feature #1592 (t = 3.62)
# Rank 875: 'max' feature #6905 (t = 3.62)
# Rank 876: 'max' feature #7847 (t = 3.62)
# Rank 877: 'max' feature #6263 (t = 3.62)
# Rank 878: 'max' feature #4926 (t = 3.62)
# Rank 879: 'mean' feature #4731 (t = 3.62)
# Rank 880: 'mean' feature #212 (t = 3.62)
# Rank 881: 'max' feature #685 (t = 3.62)
# Rank 882: 'mean' feature #5140 (t = 3.62)
# Rank 883: 'max' feature #6585 (t = 3.62)
# Rank 884: 'max' feature #7261 (t = 3.61)
# Rank 885: 'mean' feature #3609 (t = 3.61)
# Rank 886: 'max' feature #5049 (t = 3.61)
# Rank 887: 'max' feature #6102 (t = 3.61)
# Rank 888: 'max' feature #2426 (t = 3.61)
# Rank 889: 'mean' feature #5396 (t = 3.61)
# Rank 890: 'mean' feature #1070 (t = 3.61)
# Rank 891: 'mean' feature #8147 (t = 3.61)
# Rank 892: 'max' feature #3986 (t = 3.61)
# Rank 893: 'mean' feature #6491 (t = 3.61)
# Rank 894: 'mean' feature #5245 (t = 3.61)
# Rank 895: 'max' feature #4002 (t = 3.60)
# Rank 896: 'max' feature #2733 (t = 3.60)
# Rank 897: 'max' feature #3123 (t = 3.60)
# Rank 898: 'mean' feature #6690 (t = 3.60)
# Rank 899: 'mean' feature #3488 (t = 3.60)
# Rank 900: 'mean' feature #5496 (t = 3.60)
# Rank 901: 'mean' feature #2891 (t = 3.60)
# Rank 902: 'mean' feature #4317 (t = 3.60)
# Rank 903: 'max' feature #3120 (t = 3.60)
# Rank 904: 'mean' feature #2826 (t = 3.60)
# Rank 905: 'mean' feature #1015 (t = 3.60)
# Rank 906: 'mean' feature #2184 (t = 3.60)
# Rank 907: 'mean' feature #5445 (t = 3.60)
# Rank 908: 'mean' feature #5684 (t = 3.59)
# Rank 909: 'max' feature #7010 (t = 3.59)
# Rank 910: 'max' feature #3957 (t = 3.59)
# Rank 911: 'max' feature #1873 (t = 3.59)
# Rank 912: 'mean' feature #1407 (t = 3.59)
# Rank 913: 'max' feature #4476 (t = 3.59)
# Rank 914: 'max' feature #222 (t = 3.59)
# Rank 915: 'mean' feature #7767 (t = 3.59)
# Rank 916: 'max' feature #5124 (t = 3.59)
# Rank 917: 'mean' feature #1852 (t = 3.59)
# Rank 918: 'max' feature #232 (t = 3.58)
# Rank 919: 'max' feature #6545 (t = 3.58)
# Rank 920: 'mean' feature #3574 (t = 3.58)
# Rank 921: 'mean' feature #86 (t = 3.58)
# Rank 922: 'max' feature #7478 (t = 3.58)
# Rank 923: 'max' feature #359 (t = 3.58)
# Rank 924: 'max' feature #3316 (t = 3.58)
# Rank 925: 'max' feature #4552 (t = 3.58)
# Rank 926: 'mean' feature #7804 (t = 3.58)
# Rank 927: 'max' feature #7961 (t = 3.58)
# Rank 928: 'mean' feature #7807 (t = 3.58)
# Rank 929: 'mean' feature #6030 (t = 3.57)
# Rank 930: 'max' feature #4867 (t = 3.57)
# Rank 931: 'max' feature #1919 (t = 3.57)
# Rank 932: 'max' feature #6911 (t = 3.57)
# Rank 933: 'mean' feature #1420 (t = 3.57)
# Rank 934: 'mean' feature #10 (t = 3.57)
# Rank 935: 'max' feature #451 (t = 3.57)
# Rank 936: 'mean' feature #6967 (t = 3.57)
# Rank 937: 'max' feature #2400 (t = 3.57)
# Rank 938: 'mean' feature #6663 (t = 3.57)
# Rank 939: 'mean' feature #5645 (t = 3.57)
# Rank 940: 'mean' feature #5852 (t = 3.57)
# Rank 941: 'mean' feature #763 (t = 3.57)
# Rank 942: 'max' feature #1279 (t = 3.57)
# Rank 943: 'mean' feature #422 (t = 3.57)
# Rank 944: 'mean' feature #3525 (t = 3.57)
# Rank 945: 'max' feature #1189 (t = 3.57)
# Rank 946: 'mean' feature #5576 (t = 3.57)
# Rank 947: 'max' feature #7890 (t = 3.57)
# Rank 948: 'mean' feature #3050 (t = 3.57)
# Rank 949: 'mean' feature #5353 (t = 3.56)
# Rank 950: 'mean' feature #2253 (t = 3.56)
# Rank 951: 'max' feature #5995 (t = 3.56)
# Rank 952: 'mean' feature #4033 (t = 3.56)
# Rank 953: 'mean' feature #4205 (t = 3.56)
# Rank 954: 'mean' feature #6302 (t = 3.56)
# Rank 955: 'mean' feature #2232 (t = 3.56)
# Rank 956: 'max' feature #3507 (t = 3.56)
# Rank 957: 'max' feature #2672 (t = 3.56)
# Rank 958: 'max' feature #3750 (t = 3.56)
# Rank 959: 'max' feature #427 (t = 3.56)
# Rank 960: 'max' feature #2435 (t = 3.55)
# Rank 961: 'mean' feature #935 (t = 3.55)
# Rank 962: 'max' feature #3898 (t = 3.55)
# Rank 963: 'mean' feature #793 (t = 3.55)
# Rank 964: 'mean' feature #6974 (t = 3.55)
# Rank 965: 'mean' feature #6650 (t = 3.55)
# Rank 966: 'mean' feature #7578 (t = 3.55)
# Rank 967: 'mean' feature #6513 (t = 3.55)
# Rank 968: 'max' feature #6473 (t = 3.55)
# Rank 969: 'mean' feature #4915 (t = 3.55)
# Rank 970: 'mean' feature #3775 (t = 3.55)
# Rank 971: 'max' feature #5171 (t = 3.55)
# Rank 972: 'max' feature #2858 (t = 3.55)
# Rank 973: 'max' feature #1501 (t = 3.55)
# Rank 974: 'mean' feature #871 (t = 3.55)
# Rank 975: 'mean' feature #5379 (t = 3.55)
# Rank 976: 'mean' feature #2322 (t = 3.55)
# Rank 977: 'mean' feature #5568 (t = 3.55)
# Rank 978: 'max' feature #7371 (t = 3.55)
# Rank 979: 'mean' feature #7104 (t = 3.55)
# Rank 980: 'max' feature #4178 (t = 3.54)
# Rank 981: 'max' feature #1076 (t = 3.54)
# Rank 982: 'max' feature #5568 (t = 3.54)
# Rank 983: 'mean' feature #1205 (t = 3.54)
# Rank 984: 'mean' feature #323 (t = 3.54)
# Rank 985: 'mean' feature #4616 (t = 3.54)
# Rank 986: 'max' feature #2517 (t = 3.54)
# Rank 987: 'max' feature #7213 (t = 3.54)
# Rank 988: 'mean' feature #4918 (t = 3.54)
# Rank 989: 'max' feature #242 (t = 3.54)
# Rank 990: 'max' feature #3438 (t = 3.54)
# Rank 991: 'max' feature #8149 (t = 3.54)
# Rank 992: 'mean' feature #3703 (t = 3.54)
# Rank 993: 'mean' feature #5315 (t = 3.54)
# Rank 994: 'mean' feature #7908 (t = 3.54)
# Rank 995: 'max' feature #2902 (t = 3.54)
# Rank 996: 'mean' feature #699 (t = 3.53)
# Rank 997: 'max' feature #3941 (t = 3.53)
# Rank 998: 'max' feature #2548 (t = 3.53)
# Rank 999: 'max' feature #1226 (t = 3.53)
# Rank 1000: 'mean' feature #4589 (t = 3.53)
# /tmp/ipykernel_562009/4004282485.py:8: RuntimeWarning: invalid value encountered in divide
#   t_stats = np.abs((X_pos.mean(0) - X_neg.mean(0)) /

# %%
top_idx = ranked_idx[:1000]
X_test = X_test_all_feat[:, top_idx]
X_val = X_val_all_feat[:, top_idx]
X_top = Xc[:, top_idx]      

X_train = X_top
y_train = y

# %%
# 5) Train with L1 logistic regression & balanced class weights
clf = make_pipeline(
    StandardScaler(),
    LogisticRegression(
        penalty="l1",
        solver="saga",
        # class_weight="balanced",
        C=1.0,
        max_iter=2000,
        random_state=42
    )
)
clf.fit(X_train, y_train)
clf.fit(X_train, y_train)

# 6) Evaluate
y_pred   = clf.predict(X_test)
y_probs  = clf.predict_proba(X_test)[:,1]

print(classification_report(y_test, y_pred))
print("ROC AUC:", roc_auc_score(y_test, y_probs))

# 7) Inspect which of your top-1000 actually got nonzero weights
lr = clf.named_steps["logisticregression"]
coefs = lr.coef_.ravel()
nz    = np.where(coefs != 0)[0]
# Out:
#               precision    recall  f1-score   support
#
#            0       0.25      0.26      0.26       222
#            1       0.79      0.79      0.79       793
#
#     accuracy                           0.67      1015
#    macro avg       0.52      0.52      0.52      1015
# weighted avg       0.67      0.67      0.67      1015
#
# ROC AUC: 0.5416141235813366

# %%
param_grid = {"logisticregression__C": [0.01, 0.1, 1, 10, 100]}

pipeline = make_pipeline(
    StandardScaler(),
    LogisticRegression(
        penalty="l2",
        solver="saga",    
        # solver="liblinear",    
        # class_weight="balanced",
        max_iter=7000,
        random_state=42
    )
)

search = GridSearchCV(
    pipeline,
    param_grid,
    cv=5,
    scoring="roc_auc",
    n_jobs=-1,
    verbose=1
)

# X_sparse = sparse.csr_matrix(X_train) 
search.fit(X_train, y_train)

print("Best C (inverse reg. strength):", search.best_params_["logisticregression__C"])
print("CV ROC AUC:", search.best_score_)


best_clf = search.best_estimator_
y_pred_probs = best_clf.predict_proba(X_test)[:, 1]
y_pred       = best_clf.predict(X_test)

print(classification_report(y_test, y_pred))
print("Test ROC AUC:", roc_auc_score(y_test, y_pred_probs))
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# /home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Best C (inverse reg. strength): 0.01
# CV ROC AUC: 0.7284655699201593
#               precision    recall  f1-score   support
#
#            0       0.32      0.21      0.25       222
#            1       0.80      0.87      0.83       793
#
#     accuracy                           0.73      1015
#    macro avg       0.56      0.54      0.54      1015
# weighted avg       0.69      0.73      0.71      1015
#
# Test ROC AUC: 0.5598195926064778

# %%
# 1) Build your sparse training matrix once
X_sparse = sparse.csr_matrix(X_train)

# 2) Swap out StandardScaler (which densifies) for MaxAbsScaler
#    or StandardScaler(with_mean=False) so we never convert to dense.
# 3) Change penalty to "l1" (saga supports L1) to get a sparse model.
param_grid = {
    "logisticregression__C": [0.01, 0.1, 1, 10, 100]
}

pipeline = make_pipeline(
    MaxAbsScaler(),  
    LogisticRegression(
        penalty="l1",
        solver="saga",
        max_iter=7000,
        random_state=42,
        n_jobs=-1
    )
)

search = GridSearchCV(
    pipeline,
    param_grid,
    cv=5,
    scoring="roc_auc",
    n_jobs=-1,
    verbose=1
)

# 4) Fit on your CSR matrix
search.fit(X_sparse, y_train)

print("Best C (inverse reg. strength):", search.best_params_["logisticregression__C"])
print("CV ROC AUC:", search.best_score_)

# 5) Evaluate on your (also sparse) test set
X_test_sparse = sparse.csr_matrix(X_test)
best_clf = search.best_estimator_
y_pred_probs = best_clf.predict_proba(X_test_sparse)[:, 1]
y_pred       = best_clf.predict(X_test_sparse)

print(classification_report(y_test, y_pred))
print("Test ROC AUC:", roc_auc_score(y_test, y_pred_probs))
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# Traceback (most recent call last):
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_comm.py", line 422, in _on_run
#     cmd.send(self.sock)
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_net_command.py", line 111, in send
#     sock.sendall(("Content-Length: %s\r\n\r\n" % len(as_bytes)).encode("ascii"))
# OSError: [Errno 9] Bad file descriptor
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_daemon_thread.py", line 53, in run
#     self._on_run()
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_comm.py", line 432, in _on_run
#     self.py_db.dispose_and_kill_all_pydevd_threads()
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/pydevd.py", line 2558, in dispose_and_kill_all_pydevd_threads
#     self._client_socket.close()
#   File "/usr/lib/python3.10/socket.py", line 502, in close
#     self._real_close()
#   File "/usr/lib/python3.10/socket.py", line 496, in _real_close
#     _ss.close(self)
# OSError: [Errno 9] Bad file descriptor
# Traceback (most recent call last):
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_comm.py", line 422, in _on_run
#     cmd.send(self.sock)
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_net_command.py", line 111, in send
#     sock.sendall(("Content-Length: %s\r\n\r\n" % len(as_bytes)).encode("ascii"))
# OSError: [Errno 9] Bad file descriptor
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_daemon_thread.py", line 53, in run
#     self._on_run()
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_comm.py", line 432, in _on_run
#     self.py_db.dispose_and_kill_all_pydevd_threads()
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/pydevd.py", line 2558, in dispose_and_kill_all_pydevd_threads
#     self._client_socket.close()
#   File "/usr/lib/python3.10/socket.py", line 502, in close
#     self._real_close()
#   File "/usr/lib/python3.10/socket.py", line 496, in _real_close
#     _ss.close(self)
# OSError: [Errno 9] Bad file descriptor
# Traceback (most recent call last):
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_comm.py", line 422, in _on_run
#     cmd.send(self.sock)
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_net_command.py", line 111, in send
#     sock.sendall(("Content-Length: %s\r\n\r\n" % len(as_bytes)).encode("ascii"))
# OSError: [Errno 9] Bad file descriptor
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_daemon_thread.py", line 53, in run
#     self._on_run()
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_comm.py", line 432, in _on_run
#     self.py_db.dispose_and_kill_all_pydevd_threads()
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/pydevd.py", line 2558, in dispose_and_kill_all_pydevd_threads
#     self._client_socket.close()
#   File "/usr/lib/python3.10/socket.py", line 502, in close
#     self._real_close()
#   File "/usr/lib/python3.10/socket.py", line 496, in _real_close
#     _ss.close(self)
# OSError: [Errno 9] Bad file descriptor
# Traceback (most recent call last):
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_comm.py", line 422, in _on_run
#     cmd.send(self.sock)
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_net_command.py", line 111, in send
#     sock.sendall(("Content-Length: %s\r\n\r\n" % len(as_bytes)).encode("ascii"))
# OSError: [Errno 9] Bad file descriptor
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_daemon_thread.py", line 53, in run
#     self._on_run()
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_comm.py", line 432, in _on_run
#     self.py_db.dispose_and_kill_all_pydevd_threads()
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/pydevd.py", line 2558, in dispose_and_kill_all_pydevd_threads
#     self._client_socket.close()
#   File "/usr/lib/python3.10/socket.py", line 502, in close
#     self._real_close()
#   File "/usr/lib/python3.10/socket.py", line 496, in _real_close
#     _ss.close(self)
# OSError: [Errno 9] Bad file descriptor
# Traceback (most recent call last):
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_comm.py", line 422, in _on_run
#     cmd.send(self.sock)
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_net_command.py", line 111, in send
#     sock.sendall(("Content-Length: %s\r\n\r\n" % len(as_bytes)).encode("ascii"))
# OSError: [Errno 9] Bad file descriptor
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_daemon_thread.py", line 53, in run
#     self._on_run()
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_comm.py", line 432, in _on_run
#     self.py_db.dispose_and_kill_all_pydevd_threads()
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/pydevd.py", line 2558, in dispose_and_kill_all_pydevd_threads
#     self._client_socket.close()
#   File "/usr/lib/python3.10/socket.py", line 502, in close
#     self._real_close()
#   File "/usr/lib/python3.10/socket.py", line 496, in _real_close
#     _ss.close(self)
# OSError: [Errno 9] Bad file descriptor
# Traceback (most recent call last):
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_comm.py", line 422, in _on_run
#     cmd.send(self.sock)
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_net_command.py", line 111, in send
#     sock.sendall(("Content-Length: %s\r\n\r\n" % len(as_bytes)).encode("ascii"))
# OSError: [Errno 9] Bad file descriptor
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_daemon_thread.py", line 53, in run
#     self._on_run()
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_comm.py", line 432, in _on_run
#     self.py_db.dispose_and_kill_all_pydevd_threads()
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/pydevd.py", line 2558, in dispose_and_kill_all_pydevd_threads
#     self._client_socket.close()
#   File "/usr/lib/python3.10/socket.py", line 502, in close
#     self._real_close()
#   File "/usr/lib/python3.10/socket.py", line 496, in _real_close
#     _ss.close(self)
# OSError: [Errno 9] Bad file descriptor
# Traceback (most recent call last):
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_comm.py", line 422, in _on_run
#     cmd.send(self.sock)
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_net_command.py", line 111, in send
#     sock.sendall(("Content-Length: %s\r\n\r\n" % len(as_bytes)).encode("ascii"))
# OSError: [Errno 9] Bad file descriptor
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_daemon_thread.py", line 53, in run
#     self._on_run()
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_comm.py", line 432, in _on_run
#     self.py_db.dispose_and_kill_all_pydevd_threads()
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/pydevd.py", line 2558, in dispose_and_kill_all_pydevd_threads
#     self._client_socket.close()
#   File "/usr/lib/python3.10/socket.py", line 502, in close
#     self._real_close()
#   File "/usr/lib/python3.10/socket.py", line 496, in _real_close
#     _ss.close(self)
# OSError: [Errno 9] Bad file descriptor
# Traceback (most recent call last):
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_comm.py", line 422, in _on_run
#     cmd.send(self.sock)
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_net_command.py", line 111, in send
#     sock.sendall(("Content-Length: %s\r\n\r\n" % len(as_bytes)).encode("ascii"))
# OSError: [Errno 9] Bad file descriptor
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_daemon_thread.py", line 53, in run
#     self._on_run()
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_comm.py", line 432, in _on_run
#     self.py_db.dispose_and_kill_all_pydevd_threads()
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/pydevd.py", line 2558, in dispose_and_kill_all_pydevd_threads
#     self._client_socket.close()
#   File "/usr/lib/python3.10/socket.py", line 502, in close
#     self._real_close()
#   File "/usr/lib/python3.10/socket.py", line 496, in _real_close
#     _ss.close(self)
# OSError: [Errno 9] Bad file descriptor
# Traceback (most recent call last):
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_comm.py", line 422, in _on_run
#     cmd.send(self.sock)
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_net_command.py", line 111, in send
#     sock.sendall(("Content-Length: %s\r\n\r\n" % len(as_bytes)).encode("ascii"))
# OSError: [Errno 9] Bad file descriptor
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_daemon_thread.py", line 53, in run
#     self._on_run()
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_comm.py", line 432, in _on_run
#     self.py_db.dispose_and_kill_all_pydevd_threads()
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/pydevd.py", line 2558, in dispose_and_kill_all_pydevd_threads
#     self._client_socket.close()
#   File "/usr/lib/python3.10/socket.py", line 502, in close
#     self._real_close()
#   File "/usr/lib/python3.10/socket.py", line 496, in _real_close
#     _ss.close(self)
# OSError: [Errno 9] Bad file descriptor
# Traceback (most recent call last):
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_comm.py", line 422, in _on_run
#     cmd.send(self.sock)
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_net_command.py", line 111, in send
#     sock.sendall(("Content-Length: %s\r\n\r\n" % len(as_bytes)).encode("ascii"))
# OSError: [Errno 9] Bad file descriptor
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_daemon_thread.py", line 53, in run
#     self._on_run()
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_comm.py", line 432, in _on_run
#     self.py_db.dispose_and_kill_all_pydevd_threads()
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/pydevd.py", line 2558, in dispose_and_kill_all_pydevd_threads
#     self._client_socket.close()
#   File "/usr/lib/python3.10/socket.py", line 502, in close
#     self._real_close()
#   File "/usr/lib/python3.10/socket.py", line 496, in _real_close
#     _ss.close(self)
# OSError: [Errno 9] Bad file descriptor
# Traceback (most recent call last):
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_comm.py", line 422, in _on_run
#     cmd.send(self.sock)
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_net_command.py", line 111, in send
#     sock.sendall(("Content-Length: %s\r\n\r\n" % len(as_bytes)).encode("ascii"))
# OSError: [Errno 9] Bad file descriptor
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_daemon_thread.py", line 53, in run
#     self._on_run()
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_comm.py", line 432, in _on_run
#     self.py_db.dispose_and_kill_all_pydevd_threads()
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/pydevd.py", line 2558, in dispose_and_kill_all_pydevd_threads
#     self._client_socket.close()
#   File "/usr/lib/python3.10/socket.py", line 502, in close
#     self._real_close()
#   File "/usr/lib/python3.10/socket.py", line 496, in _real_close
#     _ss.close(self)
# OSError: [Errno 9] Bad file descriptor
# Traceback (most recent call last):
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_comm.py", line 422, in _on_run
#     cmd.send(self.sock)
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_net_command.py", line 111, in send
#     sock.sendall(("Content-Length: %s\r\n\r\n" % len(as_bytes)).encode("ascii"))
# OSError: [Errno 9] Bad file descriptor
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_daemon_thread.py", line 53, in run
#     self._on_run()
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_comm.py", line 432, in _on_run
#     self.py_db.dispose_and_kill_all_pydevd_threads()
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/pydevd.py", line 2558, in dispose_and_kill_all_pydevd_threads
#     self._client_socket.close()
#   File "/usr/lib/python3.10/socket.py", line 502, in close
#     self._real_close()
#   File "/usr/lib/python3.10/socket.py", line 496, in _real_close
#     _ss.close(self)
# OSError: [Errno 9] Bad file descriptor
# Traceback (most recent call last):
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_comm.py", line 422, in _on_run
#     cmd.send(self.sock)
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_net_command.py", line 111, in send
#     sock.sendall(("Content-Length: %s\r\n\r\n" % len(as_bytes)).encode("ascii"))
# OSError: [Errno 9] Bad file descriptor
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_daemon_thread.py", line 53, in run
#     self._on_run()
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_comm.py", line 432, in _on_run
#     self.py_db.dispose_and_kill_all_pydevd_threads()
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/pydevd.py", line 2558, in dispose_and_kill_all_pydevd_threads
#     self._client_socket.close()
#   File "/usr/lib/python3.10/socket.py", line 502, in close
#     self._real_close()
#   File "/usr/lib/python3.10/socket.py", line 496, in _real_close
#     _ss.close(self)
# OSError: [Errno 9] Bad file descriptor
# Traceback (most recent call last):
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_comm.py", line 422, in _on_run
#     cmd.send(self.sock)
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_net_command.py", line 111, in send
#     sock.sendall(("Content-Length: %s\r\n\r\n" % len(as_bytes)).encode("ascii"))
# OSError: [Errno 9] Bad file descriptor
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_daemon_thread.py", line 53, in run
#     self._on_run()
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_comm.py", line 432, in _on_run
#     self.py_db.dispose_and_kill_all_pydevd_threads()
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/pydevd.py", line 2558, in dispose_and_kill_all_pydevd_threads
#     self._client_socket.close()
#   File "/usr/lib/python3.10/socket.py", line 502, in close
#     self._real_close()
#   File "/usr/lib/python3.10/socket.py", line 496, in _real_close
#     _ss.close(self)
# OSError: [Errno 9] Bad file descriptor
# Traceback (most recent call last):
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_comm.py", line 422, in _on_run
#     cmd.send(self.sock)
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_net_command.py", line 111, in send
#     sock.sendall(("Content-Length: %s\r\n\r\n" % len(as_bytes)).encode("ascii"))
# OSError: [Errno 9] Bad file descriptor
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_daemon_thread.py", line 53, in run
#     self._on_run()
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_comm.py", line 432, in _on_run
#     self.py_db.dispose_and_kill_all_pydevd_threads()
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/pydevd.py", line 2558, in dispose_and_kill_all_pydevd_threads
#     self._client_socket.close()
#   File "/usr/lib/python3.10/socket.py", line 502, in close
#     self._real_close()
#   File "/usr/lib/python3.10/socket.py", line 496, in _real_close
#     _ss.close(self)
# OSError: [Errno 9] Bad file descriptor
# Traceback (most recent call last):
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_comm.py", line 422, in _on_run
#     cmd.send(self.sock)
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_net_command.py", line 111, in send
#     sock.sendall(("Content-Length: %s\r\n\r\n" % len(as_bytes)).encode("ascii"))
# OSError: [Errno 9] Bad file descriptor
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_daemon_thread.py", line 53, in run
#     self._on_run()
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_comm.py", line 432, in _on_run
#     self.py_db.dispose_and_kill_all_pydevd_threads()
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/pydevd.py", line 2558, in dispose_and_kill_all_pydevd_threads
#     self._client_socket.close()
#   File "/usr/lib/python3.10/socket.py", line 502, in close
#     self._real_close()
#   File "/usr/lib/python3.10/socket.py", line 496, in _real_close
#     _ss.close(self)
# OSError: [Errno 9] Bad file descriptor
# Traceback (most recent call last):
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_comm.py", line 422, in _on_run
#     cmd.send(self.sock)
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_net_command.py", line 111, in send
#     sock.sendall(("Content-Length: %s\r\n\r\n" % len(as_bytes)).encode("ascii"))
# OSError: [Errno 9] Bad file descriptor
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_daemon_thread.py", line 53, in run
#     self._on_run()
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_comm.py", line 432, in _on_run
#     self.py_db.dispose_and_kill_all_pydevd_threads()
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/pydevd.py", line 2558, in dispose_and_kill_all_pydevd_threads
#     self._client_socket.close()
#   File "/usr/lib/python3.10/socket.py", line 502, in close
#     self._real_close()
#   File "/usr/lib/python3.10/socket.py", line 496, in _real_close
#     _ss.close(self)
# OSError: [Errno 9] Bad file descriptor
# Traceback (most recent call last):
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_comm.py", line 422, in _on_run
#     cmd.send(self.sock)
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_net_command.py", line 111, in send
#     sock.sendall(("Content-Length: %s\r\n\r\n" % len(as_bytes)).encode("ascii"))
# OSError: [Errno 9] Bad file descriptor
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_daemon_thread.py", line 53, in run
#     self._on_run()
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_comm.py", line 432, in _on_run
#     self.py_db.dispose_and_kill_all_pydevd_threads()
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/pydevd.py", line 2558, in dispose_and_kill_all_pydevd_threads
#     self._client_socket.close()
#   File "/usr/lib/python3.10/socket.py", line 502, in close
#     self._real_close()
#   File "/usr/lib/python3.10/socket.py", line 496, in _real_close
#     _ss.close(self)
# OSError: [Errno 9] Bad file descriptor
# Traceback (most recent call last):
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_comm.py", line 422, in _on_run
#     cmd.send(self.sock)
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_net_command.py", line 111, in send
#     sock.sendall(("Content-Length: %s\r\n\r\n" % len(as_bytes)).encode("ascii"))
# OSError: [Errno 9] Bad file descriptor
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_daemon_thread.py", line 53, in run
#     self._on_run()
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_comm.py", line 432, in _on_run
#     self.py_db.dispose_and_kill_all_pydevd_threads()
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/pydevd.py", line 2558, in dispose_and_kill_all_pydevd_threads
#     self._client_socket.close()
#   File "/usr/lib/python3.10/socket.py", line 502, in close
#     self._real_close()
#   File "/usr/lib/python3.10/socket.py", line 496, in _real_close
#     _ss.close(self)
# OSError: [Errno 9] Bad file descriptor
# Traceback (most recent call last):
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_comm.py", line 422, in _on_run
#     cmd.send(self.sock)
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_net_command.py", line 111, in send
#     sock.sendall(("Content-Length: %s\r\n\r\n" % len(as_bytes)).encode("ascii"))
# OSError: [Errno 9] Bad file descriptor
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_daemon_thread.py", line 53, in run
#     self._on_run()
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_comm.py", line 432, in _on_run
#     self.py_db.dispose_and_kill_all_pydevd_threads()
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/pydevd.py", line 2558, in dispose_and_kill_all_pydevd_threads
#     self._client_socket.close()
#   File "/usr/lib/python3.10/socket.py", line 502, in close
#     self._real_close()
#   File "/usr/lib/python3.10/socket.py", line 496, in _real_close
#     _ss.close(self)
# OSError: [Errno 9] Bad file descriptor
# Traceback (most recent call last):
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_comm.py", line 422, in _on_run
#     cmd.send(self.sock)
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_net_command.py", line 111, in send
#     sock.sendall(("Content-Length: %s\r\n\r\n" % len(as_bytes)).encode("ascii"))
# OSError: [Errno 9] Bad file descriptor
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_daemon_thread.py", line 53, in run
#     self._on_run()
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_comm.py", line 432, in _on_run
#     self.py_db.dispose_and_kill_all_pydevd_threads()
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/pydevd.py", line 2558, in dispose_and_kill_all_pydevd_threads
#     self._client_socket.close()
#   File "/usr/lib/python3.10/socket.py", line 502, in close
#     self._real_close()
#   File "/usr/lib/python3.10/socket.py", line 496, in _real_close
#     _ss.close(self)
# OSError: [Errno 9] Bad file descriptor
# 1907.23s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Traceback (most recent call last):
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_comm.py", line 422, in _on_run
#     cmd.send(self.sock)
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_net_command.py", line 111, in send
#     sock.sendall(("Content-Length: %s\r\n\r\n" % len(as_bytes)).encode("ascii"))
# OSError: [Errno 9] Bad file descriptor
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_daemon_thread.py", line 53, in run
#     self._on_run()
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_comm.py", line 432, in _on_run
#     self.py_db.dispose_and_kill_all_pydevd_threads()
#   File "/home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/pydevd.py", line 2558, in dispose_and_kill_all_pydevd_threads
#     self._client_socket.close()
#   File "/usr/lib/python3.10/socket.py", line 502, in close
#     self._real_close()
#   File "/usr/lib/python3.10/socket.py", line 496, in _real_close
#     _ss.close(self)
# OSError: [Errno 9] Bad file descriptor
# 1907.46s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 1907.68s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 1907.91s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 1908.15s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 1908.35s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 1908.57s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 1908.78s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 1909.02s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 1909.25s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 1909.48s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 1909.71s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 1909.93s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 1910.17s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 1910.37s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 1910.59s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 1910.84s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 1911.03s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 1911.25s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 1911.49s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 1911.73s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 1911.96s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# /home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Best C (inverse reg. strength): 1
# CV ROC AUC: 0.7155618941404921
#               precision    recall  f1-score   support
#
#            0       0.27      0.15      0.19       222
#            1       0.79      0.89      0.84       793
#
#     accuracy                           0.73      1015
#    macro avg       0.53      0.52      0.51      1015
# weighted avg       0.68      0.73      0.69      1015
#
# Test ROC AUC: 0.5670449768810425

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
X_train_t = torch.from_numpy(X_train).float().to(device)
y_train_t = torch.from_numpy(y_train).float().unsqueeze(1).to(device)
X_test_t  = torch.from_numpy(X_test).float().to(device)
y_test_t  = torch.from_numpy(y_test).float().unsqueeze(1).to(device)

# DataLoader
train_ds = TensorDataset(X_train_t, y_train_t)
train_dl = DataLoader(train_ds, batch_size=32, shuffle=True, drop_last=True)


class ShallowMLP(nn.Module):
    def __init__(self, input_dim, hidden_dim=256, dropout=0.5):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.BatchNorm1d(hidden_dim),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_dim, 1),
            nn.Sigmoid()
        )
    def forward(self, x):
        return self.net(x)

model = ShallowMLP(input_dim=X_top.shape[1]).to(device)

optimizer = torch.optim.AdamW(model.parameters(), lr=1e-3, weight_decay=1e-5)
criterion = nn.BCELoss()

# 4) Training loop
n_epochs = 30
for epoch in range(1, n_epochs+1):
    model.train()
    total_loss = 0.0
    for xb, yb in train_dl:
        pred = model(xb)
        loss = criterion(pred, yb)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * xb.size(0)
    avg_loss = total_loss / len(train_dl.dataset)
    print(f"Epoch {epoch:2d}: train loss = {avg_loss:.4f}")

# 5) Evaluation
model.eval()
with torch.no_grad():
    y_prob = model(X_test_t).cpu().numpy().flatten()
    y_pred = (y_prob >= 0.5).astype(int)

print("\nClassification Report:")
print(classification_report(y_test, y_pred))
print("Test ROC AUC:", roc_auc_score(y_test, y_prob))
# Out:
# Epoch  1: train loss = 0.4804
# Epoch  2: train loss = 0.4061
# Epoch  3: train loss = 0.3606
# Epoch  4: train loss = 0.3332
# Epoch  5: train loss = 0.2996
# Epoch  6: train loss = 0.2704
# Epoch  7: train loss = 0.2355
# Epoch  8: train loss = 0.2111
# Epoch  9: train loss = 0.1851
# Epoch 10: train loss = 0.1704
# Epoch 11: train loss = 0.1536
# Epoch 12: train loss = 0.1352
# Epoch 13: train loss = 0.1236
# Epoch 14: train loss = 0.1108
# Epoch 15: train loss = 0.1030
# Epoch 16: train loss = 0.0836
# Epoch 17: train loss = 0.0814
# Epoch 18: train loss = 0.0670
# Epoch 19: train loss = 0.0660
# Epoch 20: train loss = 0.0612
# Epoch 21: train loss = 0.0560
# Epoch 22: train loss = 0.0518
# Epoch 23: train loss = 0.0595
# Epoch 24: train loss = 0.0611
# Epoch 25: train loss = 0.0514
# Epoch 26: train loss = 0.0486
# Epoch 27: train loss = 0.0483
# Epoch 28: train loss = 0.0520
# Epoch 29: train loss = 0.0522
# Epoch 30: train loss = 0.0445
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.29      0.26      0.27       222
#            1       0.80      0.82      0.81       793
#
#     accuracy                           0.70      1015
#    macro avg       0.54      0.54      0.54      1015
# weighted avg       0.69      0.70      0.69      1015
#
# Test ROC AUC: 0.5582006975449598

# %%
dtrain = xgb.DMatrix(X_train, label=y_train)
dtest  = xgb.DMatrix(X_test,  label=y_test)


scale_pos_weight = float((y_train == 0).sum()) / (y_train == 1).sum()


params = {
    "objective":        "binary:logistic",
    "eval_metric":      "auc",
    "scale_pos_weight": scale_pos_weight,
    "tree_method":      "hist",       
    "grow_policy":      "lossguide",  
    "max_depth":        6,
    "learning_rate":    0.1,
    "subsample":        0.8,
    "colsample_bytree": 0.8,
    "random_state":     42,
    "verbosity":        1
}


cv_results = xgb.cv(
    params,
    dtrain,
    num_boost_round=1000,
    nfold=5,
    early_stopping_rounds=20,
    metrics="auc",
    seed=42,
    as_pandas=True,
    verbose_eval=50
)
best_rounds = len(cv_results)
print(f"Optimal boosting rounds: {best_rounds}")


bst = xgb.train(
    params,
    dtrain,
    num_boost_round=best_rounds
)


y_prob = bst.predict(dtest)
y_pred = (y_prob >= 0.5).astype(int)

print("\nClassification Report:")
print(classification_report(y_test, y_pred))
print("Test ROC AUC:", roc_auc_score(y_test, y_prob))
# Out:
# [0]	train-auc:0.79059+0.01417	test-auc:0.59616+0.04367
# [50]	train-auc:0.99999+0.00001	test-auc:0.69730+0.02020
# [100]	train-auc:1.00000+0.00000	test-auc:0.70976+0.02243
# [131]	train-auc:1.00000+0.00000	test-auc:0.71024+0.02205
# Optimal boosting rounds: 112
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.33      0.23      0.27       222
#            1       0.80      0.87      0.83       793
#
#     accuracy                           0.73      1015
#    macro avg       0.57      0.55      0.55      1015
# weighted avg       0.70      0.73      0.71      1015
#
# Test ROC AUC: 0.5972075480272201

# %%
# 3) Convert to tensors and move to device
def to_tensor(x, y):
    xt = torch.from_numpy(x).float().to(device)
    yt = torch.from_numpy(y).float().unsqueeze(1).to(device)
    return xt, yt

X_tr_t, y_tr_t = to_tensor(X_train, y_train)
X_val_t, y_val_t = to_tensor(X_val, y_val)
X_test_t, y_test_t = to_tensor(X_test, y_test)

# 4) DataLoaders
batch_size = 32
train_ds = TensorDataset(X_tr_t, y_tr_t)
val_ds   = TensorDataset(X_val_t, y_val_t)
train_dl = DataLoader(train_ds, batch_size=batch_size, shuffle=True, drop_last=True)
val_dl   = DataLoader(val_ds,   batch_size=batch_size, shuffle=False)

# 5) Model definition
class ShallowMLP(nn.Module):
    def __init__(self, input_dim, hidden_dim=256, dropout=0.5):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.BatchNorm1d(hidden_dim),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_dim, 1),
            nn.Sigmoid()
        )
    def forward(self, x):
        return self.net(x)

model = ShallowMLP(input_dim=X_train.shape[1]).to(device)

# 6) Optimizer and loss
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-3, weight_decay=1e-5)
criterion = nn.BCELoss()

# 7) Training with validation
n_epochs = 20
for epoch in range(1, n_epochs + 1):
    # Training
    model.train()
    total_tr_loss = 0.0
    for xb, yb in train_dl:
        optimizer.zero_grad()
        pred = model(xb)
        loss = criterion(pred, yb)
        loss.backward()
        optimizer.step()
        total_tr_loss += loss.item() * xb.size(0)
    avg_tr_loss = total_tr_loss / len(train_dl.dataset)

    # Validation
    model.eval()
    total_val_loss = 0.0
    with torch.no_grad():
        for xb, yb in val_dl:
            pred = model(xb)
            loss = criterion(pred, yb)
            total_val_loss += loss.item() * xb.size(0)
    avg_val_loss = total_val_loss / len(val_dl.dataset)

    print(f"Epoch {epoch:2d}: train_loss = {avg_tr_loss:.4f}, val_loss = {avg_val_loss:.4f}")

# 8) Final evaluation on test set
model.eval()
with torch.no_grad():
    y_prob = model(X_test_t).cpu().numpy().flatten()
    y_pred = (y_prob >= 0.5).astype(int)

print("\nClassification Report on Test Set:")
print(classification_report(y_test, y_pred))
print("Test ROC AUC:", roc_auc_score(y_test, y_prob))
# Out:
# Epoch  1: train_loss = 0.4802, val_loss = 0.8715
# Epoch  2: train_loss = 0.3954, val_loss = 0.5293
# Epoch  3: train_loss = 0.3588, val_loss = 1.3259
# Epoch  4: train_loss = 0.3188, val_loss = 4.0063
# Epoch  5: train_loss = 0.2955, val_loss = 10.1170
# Epoch  6: train_loss = 0.2569, val_loss = 15.0498
# Epoch  7: train_loss = 0.2334, val_loss = 15.9916
# Epoch  8: train_loss = 0.2077, val_loss = 20.1106
# Epoch  9: train_loss = 0.1821, val_loss = 26.2765
# Epoch 10: train_loss = 0.1627, val_loss = 27.4486
# Epoch 11: train_loss = 0.1380, val_loss = 36.5073
# Epoch 12: train_loss = 0.1262, val_loss = 41.6051
# Epoch 13: train_loss = 0.1112, val_loss = 41.5592
# Epoch 14: train_loss = 0.1124, val_loss = 42.2641
# Epoch 15: train_loss = 0.0900, val_loss = 52.6739
# Epoch 16: train_loss = 0.0947, val_loss = 46.9765
# Epoch 17: train_loss = 0.0870, val_loss = 57.6871
# Epoch 18: train_loss = 0.0766, val_loss = 49.2754
# Epoch 19: train_loss = 0.0774, val_loss = 64.2224
# Epoch 20: train_loss = 0.0720, val_loss = 66.2575
#
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#            0       0.26      0.15      0.19       222
#            1       0.79      0.88      0.83       793
#
#     accuracy                           0.72      1015
#    macro avg       0.52      0.51      0.51      1015
# weighted avg       0.67      0.72      0.69      1015
#
# Test ROC AUC: 0.5491519262011064
