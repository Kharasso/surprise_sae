# %%
import os
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from scipy.stats import ttest_ind
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.metrics import classification_report, roc_auc_score

# %%
npz_paths = [
    "./data/doc_features/transcript_componenttext_2010_1_features.npz",
    "./data/doc_features/transcript_componenttext_2010_2_features.npz",
    "./data/doc_features/transcript_componenttext_2011_1_features.npz",
    "./data/doc_features/transcript_componenttext_2011_2_features.npz",
    "./data/doc_features/transcript_componenttext_2012_1_features.npz",
    "./data/doc_features/transcript_componenttext_2012_2_features.npz"
]

# %%
X_list = []
y_list = []

for npz_path in npz_paths:
 
    base = os.path.splitext(os.path.basename(npz_path))[0]      
    csv_path = os.path.join(
        os.path.dirname(npz_path),
        base + "_meta.csv"                                       
    )


    data = np.load(npz_path, allow_pickle=True)
    X_concat = data["X_concat"]      # (N_docs, 2*D)
    tids = data["transcriptids"]    


    meta = pd.read_csv(csv_path)

    meta_unique = (
        meta[["transcriptid", "SUESCORE", "label"]]
        .drop_duplicates(subset="transcriptid", keep="first")
        .set_index("transcriptid")
    )

    mask_ids = np.isin(tids, meta_unique.index)
    X_filt = X_concat[mask_ids]
    tids_filt = np.array(tids)[mask_ids]


    lab_df = meta.assign(
        label=lambda df: df.SUESCORE.map(
            lambda s: 1 if s >= 0.5 else (0 if s <= -0.5 else np.nan)
        )
    )
    mask_label = lab_df.label.notna().values
    # apply the same mask in the same order as the CSV, so we use .loc on lab_df
    # but first filter lab_df to only those transcriptids in tids_filt
    Xc, y = X_filt[mask_label], meta.loc[mask_label, "label"].astype(int).values
    
    # now align X and y
    # X_final = X_filt[lab_sub.label.notna()]
    # y_final = lab_sub.label.astype(int).values

    # collect
    X_list.append(Xc)
    y_list.append(y)

# 2. concatenate all files together
Xc = np.vstack(X_list)   # shape: (sum_i N_i, 2*D)
y  = np.concatenate(y_list)  # shape: (sum_i N_i,)

print("Combined Xc shape:", Xc.shape)
print("Combined y shape: ", y.shape)
# Out:
# Combined Xc shape: (5933, 32768)
# Combined y shape:  (5933,)

# %%
# # forced resampling
# idx0 = np.where(y == 0)[0]
# idx1 = np.where(y == 1)[0]

# n = min(len(idx0), len(idx1))

# sel0 = np.random.choice(idx0, size=n, replace=False)
# sel1 = np.random.choice(idx1, size=n, replace=False)

# sel = np.concatenate([sel0, sel1])
# np.random.shuffle(sel)

# # slice out your balanced subset
# Xc = Xc[sel]
# y = y[sel]

# print("Balanced X shape:", Xc.shape)
# print("Balanced y counts:", np.bincount(y))
# Out:
# Balanced X shape: (2484, 32768)
# Balanced y counts: [1242 1242]

# %%
# # 2) Build labels and mask
# meta = meta.assign(label=lambda df: df.SUESCORE.map(lambda s: 1 if s>=0.5 else (0 if s<=-0.5 else np.nan)))
# mask = meta.label.notna().values
# Xc, y = Xc_aligned[mask], meta.loc[mask, "label"].astype(int).values

# 3A) Univariate t‐tests on each of the 2D features
D2 = Xc.shape[1]
D = D2 // 2
X_pos, X_neg = Xc[y==1], Xc[y==0]
t_stats = np.abs((X_pos.mean(0) - X_neg.mean(0)) /
                 np.sqrt(X_pos.var(0)/len(X_pos) + X_neg.var(0)/len(X_neg)))
# rank features
ranked_idx = np.argsort(-t_stats)

# Inspect top‐10:
for rank, idx in enumerate(ranked_idx[:1000], start=1):
    # print(idx)
    part = "mean" if idx < D else "max"
    # print(idx)
    # print(D)
    feat_id = idx if idx < D else idx-D
    t_val   = t_stats[idx]
    print(f"Rank {rank:2d}: {part!r} feature #{feat_id} (t = {t_val:.2f})")
# Out:
# Rank  1: 'mean' feature #13877 (t = 11.22)
# Rank  2: 'mean' feature #8430 (t = 9.67)
# Rank  3: 'max' feature #15621 (t = 9.66)
# Rank  4: 'max' feature #15738 (t = 9.33)
# Rank  5: 'mean' feature #12663 (t = 9.33)
# Rank  6: 'mean' feature #8380 (t = 9.29)
# Rank  7: 'mean' feature #14370 (t = 9.20)
# Rank  8: 'mean' feature #3147 (t = 9.09)
# Rank  9: 'mean' feature #5612 (t = 9.09)
# Rank 10: 'mean' feature #9813 (t = 8.98)
# Rank 11: 'max' feature #11273 (t = 8.96)
# Rank 12: 'max' feature #14892 (t = 8.92)
# Rank 13: 'max' feature #15085 (t = 8.88)
# Rank 14: 'mean' feature #10424 (t = 8.85)
# Rank 15: 'mean' feature #13118 (t = 8.77)
# Rank 16: 'max' feature #13000 (t = 8.73)
# Rank 17: 'max' feature #8380 (t = 8.66)
# Rank 18: 'mean' feature #1520 (t = 8.59)
# Rank 19: 'max' feature #1881 (t = 8.57)
# Rank 20: 'max' feature #10010 (t = 8.56)
# Rank 21: 'max' feature #4983 (t = 8.54)
# Rank 22: 'mean' feature #15621 (t = 8.53)
# Rank 23: 'mean' feature #8823 (t = 8.46)
# Rank 24: 'mean' feature #1712 (t = 8.38)
# Rank 25: 'mean' feature #9245 (t = 8.35)
# Rank 26: 'max' feature #12299 (t = 8.35)
# Rank 27: 'max' feature #11773 (t = 8.33)
# Rank 28: 'mean' feature #1547 (t = 8.30)
# Rank 29: 'mean' feature #10560 (t = 8.27)
# Rank 30: 'mean' feature #1477 (t = 8.26)
# Rank 31: 'max' feature #11059 (t = 8.23)
# Rank 32: 'mean' feature #4075 (t = 8.22)
# Rank 33: 'mean' feature #12865 (t = 8.21)
# Rank 34: 'mean' feature #482 (t = 8.14)
# Rank 35: 'max' feature #10560 (t = 8.10)
# Rank 36: 'mean' feature #2488 (t = 8.10)
# Rank 37: 'max' feature #13545 (t = 8.09)
# Rank 38: 'max' feature #10637 (t = 8.03)
# Rank 39: 'mean' feature #1211 (t = 8.02)
# Rank 40: 'max' feature #1541 (t = 8.02)
# Rank 41: 'mean' feature #12637 (t = 8.00)
# Rank 42: 'max' feature #3878 (t = 8.00)
# Rank 43: 'mean' feature #6270 (t = 7.98)
# Rank 44: 'mean' feature #6615 (t = 7.98)
# Rank 45: 'mean' feature #2366 (t = 7.97)
# Rank 46: 'mean' feature #12812 (t = 7.94)
# Rank 47: 'mean' feature #7357 (t = 7.93)
# Rank 48: 'mean' feature #14277 (t = 7.93)
# Rank 49: 'mean' feature #1885 (t = 7.91)
# Rank 50: 'max' feature #1211 (t = 7.89)
# Rank 51: 'max' feature #9149 (t = 7.89)
# Rank 52: 'mean' feature #6745 (t = 7.87)
# Rank 53: 'max' feature #7456 (t = 7.86)
# Rank 54: 'max' feature #13617 (t = 7.86)
# Rank 55: 'max' feature #14080 (t = 7.82)
# Rank 56: 'mean' feature #10637 (t = 7.81)
# Rank 57: 'mean' feature #12299 (t = 7.78)
# Rank 58: 'mean' feature #16278 (t = 7.74)
# Rank 59: 'mean' feature #11273 (t = 7.72)
# Rank 60: 'mean' feature #6703 (t = 7.69)
# Rank 61: 'max' feature #6902 (t = 7.69)
# Rank 62: 'max' feature #14370 (t = 7.68)
# Rank 63: 'max' feature #12865 (t = 7.67)
# Rank 64: 'max' feature #15681 (t = 7.66)
# Rank 65: 'mean' feature #6770 (t = 7.66)
# Rank 66: 'mean' feature #7804 (t = 7.64)
# Rank 67: 'max' feature #2845 (t = 7.64)
# Rank 68: 'max' feature #3549 (t = 7.64)
# Rank 69: 'mean' feature #269 (t = 7.61)
# Rank 70: 'max' feature #635 (t = 7.57)
# Rank 71: 'mean' feature #15085 (t = 7.56)
# Rank 72: 'max' feature #4600 (t = 7.55)
# Rank 73: 'mean' feature #2775 (t = 7.55)
# Rank 74: 'mean' feature #14080 (t = 7.53)
# Rank 75: 'max' feature #1547 (t = 7.53)
# Rank 76: 'mean' feature #8543 (t = 7.50)
# Rank 77: 'max' feature #7357 (t = 7.50)
# Rank 78: 'max' feature #2488 (t = 7.50)
# Rank 79: 'mean' feature #2281 (t = 7.49)
# Rank 80: 'mean' feature #7861 (t = 7.48)
# Rank 81: 'mean' feature #3990 (t = 7.48)
# Rank 82: 'max' feature #940 (t = 7.47)
# Rank 83: 'mean' feature #940 (t = 7.47)
# Rank 84: 'max' feature #3585 (t = 7.46)
# Rank 85: 'mean' feature #13545 (t = 7.46)
# Rank 86: 'mean' feature #13000 (t = 7.45)
# Rank 87: 'max' feature #1712 (t = 7.44)
# Rank 88: 'max' feature #14277 (t = 7.43)
# Rank 89: 'mean' feature #10040 (t = 7.41)
# Rank 90: 'max' feature #12812 (t = 7.40)
# Rank 91: 'max' feature #8543 (t = 7.40)
# Rank 92: 'mean' feature #6470 (t = 7.39)
# Rank 93: 'mean' feature #6281 (t = 7.38)
# Rank 94: 'mean' feature #8268 (t = 7.38)
# Rank 95: 'max' feature #133 (t = 7.36)
# Rank 96: 'max' feature #13075 (t = 7.36)
# Rank 97: 'mean' feature #4412 (t = 7.35)
# Rank 98: 'max' feature #10155 (t = 7.34)
# Rank 99: 'max' feature #14578 (t = 7.33)
# Rank 100: 'mean' feature #10303 (t = 7.31)
# Rank 101: 'max' feature #6703 (t = 7.30)
# Rank 102: 'mean' feature #8097 (t = 7.28)
# Rank 103: 'mean' feature #10421 (t = 7.27)
# Rank 104: 'mean' feature #11262 (t = 7.25)
# Rank 105: 'mean' feature #11637 (t = 7.24)
# Rank 106: 'mean' feature #14892 (t = 7.23)
# Rank 107: 'max' feature #523 (t = 7.22)
# Rank 108: 'max' feature #5240 (t = 7.22)
# Rank 109: 'mean' feature #12121 (t = 7.21)
# Rank 110: 'max' feature #9245 (t = 7.19)
# Rank 111: 'max' feature #6770 (t = 7.19)
# Rank 112: 'mean' feature #856 (t = 7.17)
# Rank 113: 'mean' feature #15738 (t = 7.16)
# Rank 114: 'mean' feature #1092 (t = 7.16)
# Rank 115: 'max' feature #2366 (t = 7.16)
# Rank 116: 'max' feature #15796 (t = 7.15)
# Rank 117: 'mean' feature #5817 (t = 7.13)
# Rank 118: 'mean' feature #10405 (t = 7.12)
# Rank 119: 'mean' feature #9735 (t = 7.12)
# Rank 120: 'mean' feature #6289 (t = 7.11)
# Rank 121: 'mean' feature #1541 (t = 7.10)
# Rank 122: 'mean' feature #12484 (t = 7.09)
# Rank 123: 'max' feature #9813 (t = 7.08)
# Rank 124: 'max' feature #12058 (t = 7.07)
# Rank 125: 'mean' feature #9611 (t = 7.06)
# Rank 126: 'mean' feature #15796 (t = 7.05)
# Rank 127: 'mean' feature #4606 (t = 7.04)
# Rank 128: 'max' feature #11218 (t = 7.03)
# Rank 129: 'max' feature #16278 (t = 7.02)
# Rank 130: 'mean' feature #1390 (t = 6.99)
# Rank 131: 'mean' feature #1174 (t = 6.99)
# Rank 132: 'mean' feature #2415 (t = 6.97)
# Rank 133: 'mean' feature #4646 (t = 6.97)
# Rank 134: 'mean' feature #6332 (t = 6.96)
# Rank 135: 'mean' feature #6211 (t = 6.95)
# Rank 136: 'max' feature #15762 (t = 6.95)
# Rank 137: 'max' feature #6289 (t = 6.95)
# Rank 138: 'max' feature #14349 (t = 6.93)
# Rank 139: 'mean' feature #911 (t = 6.92)
# Rank 140: 'max' feature #12449 (t = 6.90)
# Rank 141: 'mean' feature #6122 (t = 6.88)
# Rank 142: 'mean' feature #8989 (t = 6.86)
# Rank 143: 'mean' feature #11064 (t = 6.86)
# Rank 144: 'max' feature #10405 (t = 6.85)
# Rank 145: 'max' feature #1390 (t = 6.84)
# Rank 146: 'max' feature #1635 (t = 6.83)
# Rank 147: 'max' feature #10390 (t = 6.82)
# Rank 148: 'mean' feature #240 (t = 6.81)
# Rank 149: 'mean' feature #12015 (t = 6.81)
# Rank 150: 'max' feature #13011 (t = 6.80)
# Rank 151: 'max' feature #14199 (t = 6.79)
# Rank 152: 'mean' feature #3846 (t = 6.78)
# Rank 153: 'mean' feature #11919 (t = 6.78)
# Rank 154: 'mean' feature #14606 (t = 6.78)
# Rank 155: 'mean' feature #9686 (t = 6.77)
# Rank 156: 'mean' feature #15615 (t = 6.77)
# Rank 157: 'mean' feature #12899 (t = 6.76)
# Rank 158: 'max' feature #9502 (t = 6.74)
# Rank 159: 'mean' feature #10693 (t = 6.74)
# Rank 160: 'mean' feature #523 (t = 6.74)
# Rank 161: 'max' feature #11637 (t = 6.73)
# Rank 162: 'max' feature #255 (t = 6.73)
# Rank 163: 'mean' feature #4007 (t = 6.73)
# Rank 164: 'mean' feature #10733 (t = 6.73)
# Rank 165: 'max' feature #7797 (t = 6.72)
# Rank 166: 'mean' feature #7589 (t = 6.71)
# Rank 167: 'max' feature #1174 (t = 6.71)
# Rank 168: 'max' feature #4013 (t = 6.71)
# Rank 169: 'mean' feature #2352 (t = 6.71)
# Rank 170: 'mean' feature #10515 (t = 6.69)
# Rank 171: 'mean' feature #3078 (t = 6.67)
# Rank 172: 'mean' feature #11149 (t = 6.67)
# Rank 173: 'mean' feature #3697 (t = 6.67)
# Rank 174: 'mean' feature #14024 (t = 6.66)
# Rank 175: 'mean' feature #13972 (t = 6.66)
# Rank 176: 'max' feature #10879 (t = 6.65)
# Rank 177: 'mean' feature #12449 (t = 6.65)
# Rank 178: 'max' feature #14120 (t = 6.65)
# Rank 179: 'max' feature #6332 (t = 6.63)
# Rank 180: 'mean' feature #13617 (t = 6.62)
# Rank 181: 'max' feature #15239 (t = 6.61)
# Rank 182: 'mean' feature #216 (t = 6.60)
# Rank 183: 'max' feature #1446 (t = 6.60)
# Rank 184: 'mean' feature #9974 (t = 6.60)
# Rank 185: 'mean' feature #8424 (t = 6.59)
# Rank 186: 'mean' feature #3982 (t = 6.59)
# Rank 187: 'mean' feature #13758 (t = 6.59)
# Rank 188: 'mean' feature #3549 (t = 6.59)
# Rank 189: 'mean' feature #4084 (t = 6.59)
# Rank 190: 'mean' feature #7997 (t = 6.58)
# Rank 191: 'mean' feature #10719 (t = 6.58)
# Rank 192: 'mean' feature #9095 (t = 6.57)
# Rank 193: 'mean' feature #13011 (t = 6.56)
# Rank 194: 'max' feature #9925 (t = 6.56)
# Rank 195: 'mean' feature #2310 (t = 6.56)
# Rank 196: 'max' feature #2415 (t = 6.55)
# Rank 197: 'max' feature #720 (t = 6.55)
# Rank 198: 'mean' feature #15681 (t = 6.55)
# Rank 199: 'max' feature #3494 (t = 6.55)
# Rank 200: 'max' feature #9965 (t = 6.54)
# Rank 201: 'mean' feature #13395 (t = 6.54)
# Rank 202: 'max' feature #14040 (t = 6.53)
# Rank 203: 'mean' feature #668 (t = 6.53)
# Rank 204: 'mean' feature #7302 (t = 6.52)
# Rank 205: 'mean' feature #10460 (t = 6.52)
# Rank 206: 'max' feature #5776 (t = 6.51)
# Rank 207: 'max' feature #12942 (t = 6.51)
# Rank 208: 'mean' feature #6610 (t = 6.49)
# Rank 209: 'mean' feature #11713 (t = 6.48)
# Rank 210: 'mean' feature #14994 (t = 6.47)
# Rank 211: 'mean' feature #3130 (t = 6.47)
# Rank 212: 'max' feature #4177 (t = 6.47)
# Rank 213: 'mean' feature #13040 (t = 6.47)
# Rank 214: 'mean' feature #6083 (t = 6.45)
# Rank 215: 'mean' feature #11218 (t = 6.45)
# Rank 216: 'max' feature #4646 (t = 6.45)
# Rank 217: 'max' feature #8275 (t = 6.44)
# Rank 218: 'max' feature #1477 (t = 6.44)
# Rank 219: 'mean' feature #14608 (t = 6.43)
# Rank 220: 'max' feature #12484 (t = 6.42)
# Rank 221: 'max' feature #77 (t = 6.40)
# Rank 222: 'mean' feature #7456 (t = 6.40)
# Rank 223: 'mean' feature #10223 (t = 6.39)
# Rank 224: 'mean' feature #4983 (t = 6.38)
# Rank 225: 'max' feature #10693 (t = 6.38)
# Rank 226: 'max' feature #10710 (t = 6.37)
# Rank 227: 'mean' feature #3249 (t = 6.36)
# Rank 228: 'max' feature #15165 (t = 6.36)
# Rank 229: 'max' feature #7589 (t = 6.33)
# Rank 230: 'mean' feature #12058 (t = 6.33)
# Rank 231: 'mean' feature #11985 (t = 6.33)
# Rank 232: 'mean' feature #6055 (t = 6.32)
# Rank 233: 'max' feature #15492 (t = 6.32)
# Rank 234: 'mean' feature #2439 (t = 6.32)
# Rank 235: 'mean' feature #3998 (t = 6.32)
# Rank 236: 'mean' feature #5295 (t = 6.31)
# Rank 237: 'mean' feature #15405 (t = 6.31)
# Rank 238: 'max' feature #4485 (t = 6.30)
# Rank 239: 'max' feature #13040 (t = 6.28)
# Rank 240: 'mean' feature #2152 (t = 6.27)
# Rank 241: 'mean' feature #5273 (t = 6.27)
# Rank 242: 'mean' feature #5828 (t = 6.26)
# Rank 243: 'mean' feature #7797 (t = 6.26)
# Rank 244: 'mean' feature #6637 (t = 6.26)
# Rank 245: 'mean' feature #2440 (t = 6.25)
# Rank 246: 'mean' feature #10010 (t = 6.24)
# Rank 247: 'mean' feature #11125 (t = 6.24)
# Rank 248: 'mean' feature #12710 (t = 6.23)
# Rank 249: 'mean' feature #15783 (t = 6.23)
# Rank 250: 'mean' feature #12644 (t = 6.22)
# Rank 251: 'max' feature #10600 (t = 6.22)
# Rank 252: 'mean' feature #8310 (t = 6.21)
# Rank 253: 'mean' feature #8333 (t = 6.19)
# Rank 254: 'mean' feature #1412 (t = 6.19)
# Rank 255: 'mean' feature #8208 (t = 6.19)
# Rank 256: 'mean' feature #3585 (t = 6.19)
# Rank 257: 'mean' feature #6889 (t = 6.19)
# Rank 258: 'mean' feature #16012 (t = 6.18)
# Rank 259: 'mean' feature #10720 (t = 6.17)
# Rank 260: 'max' feature #1457 (t = 6.17)
# Rank 261: 'mean' feature #9512 (t = 6.17)
# Rank 262: 'max' feature #4789 (t = 6.17)
# Rank 263: 'mean' feature #4750 (t = 6.16)
# Rank 264: 'mean' feature #6902 (t = 6.16)
# Rank 265: 'max' feature #12500 (t = 6.16)
# Rank 266: 'max' feature #7788 (t = 6.16)
# Rank 267: 'mean' feature #8436 (t = 6.15)
# Rank 268: 'max' feature #4408 (t = 6.15)
# Rank 269: 'mean' feature #2942 (t = 6.15)
# Rank 270: 'mean' feature #11166 (t = 6.15)
# Rank 271: 'mean' feature #6254 (t = 6.15)
# Rank 272: 'max' feature #2982 (t = 6.15)
# Rank 273: 'mean' feature #1562 (t = 6.14)
# Rank 274: 'mean' feature #15128 (t = 6.14)
# Rank 275: 'mean' feature #12740 (t = 6.14)
# Rank 276: 'mean' feature #12282 (t = 6.13)
# Rank 277: 'mean' feature #4177 (t = 6.13)
# Rank 278: 'mean' feature #9717 (t = 6.12)
# Rank 279: 'mean' feature #280 (t = 6.11)
# Rank 280: 'mean' feature #7024 (t = 6.10)
# Rank 281: 'mean' feature #15165 (t = 6.10)
# Rank 282: 'mean' feature #8423 (t = 6.10)
# Rank 283: 'mean' feature #917 (t = 6.10)
# Rank 284: 'mean' feature #4264 (t = 6.10)
# Rank 285: 'max' feature #2133 (t = 6.10)
# Rank 286: 'mean' feature #7522 (t = 6.09)
# Rank 287: 'mean' feature #8413 (t = 6.08)
# Rank 288: 'mean' feature #11414 (t = 6.08)
# Rank 289: 'max' feature #3609 (t = 6.08)
# Rank 290: 'max' feature #7246 (t = 6.07)
# Rank 291: 'mean' feature #997 (t = 6.07)
# Rank 292: 'max' feature #8714 (t = 6.07)
# Rank 293: 'max' feature #13241 (t = 6.07)
# Rank 294: 'max' feature #12637 (t = 6.06)
# Rank 295: 'mean' feature #2570 (t = 6.06)
# Rank 296: 'mean' feature #14414 (t = 6.05)
# Rank 297: 'mean' feature #9736 (t = 6.05)
# Rank 298: 'mean' feature #6520 (t = 6.05)
# Rank 299: 'mean' feature #14134 (t = 6.05)
# Rank 300: 'max' feature #11049 (t = 6.05)
# Rank 301: 'max' feature #8097 (t = 6.04)
# Rank 302: 'max' feature #2281 (t = 6.04)
# Rank 303: 'mean' feature #10172 (t = 6.04)
# Rank 304: 'max' feature #4730 (t = 6.04)
# Rank 305: 'mean' feature #5767 (t = 6.04)
# Rank 306: 'max' feature #5103 (t = 6.02)
# Rank 307: 'max' feature #2440 (t = 6.02)
# Rank 308: 'max' feature #15262 (t = 6.02)
# Rank 309: 'max' feature #14189 (t = 6.01)
# Rank 310: 'max' feature #12121 (t = 6.01)
# Rank 311: 'mean' feature #9164 (t = 6.01)
# Rank 312: 'mean' feature #585 (t = 6.01)
# Rank 313: 'max' feature #14844 (t = 6.01)
# Rank 314: 'mean' feature #7517 (t = 6.01)
# Rank 315: 'mean' feature #1637 (t = 6.00)
# Rank 316: 'max' feature #8221 (t = 5.99)
# Rank 317: 'max' feature #6139 (t = 5.99)
# Rank 318: 'mean' feature #8456 (t = 5.99)
# Rank 319: 'max' feature #14994 (t = 5.97)
# Rank 320: 'mean' feature #11075 (t = 5.97)
# Rank 321: 'max' feature #4892 (t = 5.97)
# Rank 322: 'mean' feature #9230 (t = 5.96)
# Rank 323: 'mean' feature #11728 (t = 5.95)
# Rank 324: 'max' feature #11141 (t = 5.95)
# Rank 325: 'mean' feature #14622 (t = 5.94)
# Rank 326: 'mean' feature #2305 (t = 5.94)
# Rank 327: 'mean' feature #7982 (t = 5.94)
# Rank 328: 'mean' feature #3050 (t = 5.93)
# Rank 329: 'mean' feature #12497 (t = 5.93)
# Rank 330: 'mean' feature #5230 (t = 5.93)
# Rank 331: 'max' feature #939 (t = 5.92)
# Rank 332: 'mean' feature #10117 (t = 5.92)
# Rank 333: 'max' feature #8244 (t = 5.92)
# Rank 334: 'mean' feature #10929 (t = 5.92)
# Rank 335: 'mean' feature #8714 (t = 5.92)
# Rank 336: 'max' feature #13555 (t = 5.91)
# Rank 337: 'mean' feature #6535 (t = 5.91)
# Rank 338: 'max' feature #14742 (t = 5.90)
# Rank 339: 'mean' feature #8022 (t = 5.90)
# Rank 340: 'mean' feature #16097 (t = 5.90)
# Rank 341: 'max' feature #1519 (t = 5.89)
# Rank 342: 'mean' feature #12193 (t = 5.89)
# Rank 343: 'mean' feature #4329 (t = 5.88)
# Rank 344: 'mean' feature #1167 (t = 5.88)
# Rank 345: 'mean' feature #9925 (t = 5.88)
# Rank 346: 'max' feature #7722 (t = 5.88)
# Rank 347: 'mean' feature #110 (t = 5.88)
# Rank 348: 'max' feature #6370 (t = 5.88)
# Rank 349: 'mean' feature #416 (t = 5.88)
# Rank 350: 'mean' feature #9948 (t = 5.87)
# Rank 351: 'mean' feature #3962 (t = 5.87)
# Rank 352: 'max' feature #9095 (t = 5.87)
# Rank 353: 'max' feature #5343 (t = 5.86)
# Rank 354: 'mean' feature #1243 (t = 5.86)
# Rank 355: 'mean' feature #2625 (t = 5.85)
# Rank 356: 'max' feature #5485 (t = 5.85)
# Rank 357: 'max' feature #3874 (t = 5.85)
# Rank 358: 'mean' feature #10710 (t = 5.85)
# Rank 359: 'max' feature #5708 (t = 5.85)
# Rank 360: 'max' feature #257 (t = 5.83)
# Rank 361: 'max' feature #8310 (t = 5.83)
# Rank 362: 'mean' feature #484 (t = 5.83)
# Rank 363: 'mean' feature #931 (t = 5.83)
# Rank 364: 'max' feature #7462 (t = 5.83)
# Rank 365: 'mean' feature #13076 (t = 5.82)
# Rank 366: 'mean' feature #9244 (t = 5.82)
# Rank 367: 'max' feature #11064 (t = 5.82)
# Rank 368: 'max' feature #12899 (t = 5.82)
# Rank 369: 'mean' feature #9604 (t = 5.81)
# Rank 370: 'max' feature #5048 (t = 5.81)
# Rank 371: 'max' feature #3050 (t = 5.81)
# Rank 372: 'mean' feature #10769 (t = 5.81)
# Rank 373: 'mean' feature #11126 (t = 5.81)
# Rank 374: 'mean' feature #12515 (t = 5.80)
# Rank 375: 'mean' feature #12192 (t = 5.79)
# Rank 376: 'mean' feature #7755 (t = 5.79)
# Rank 377: 'max' feature #9974 (t = 5.79)
# Rank 378: 'mean' feature #9220 (t = 5.78)
# Rank 379: 'mean' feature #7462 (t = 5.78)
# Rank 380: 'mean' feature #12417 (t = 5.78)
# Rank 381: 'mean' feature #14551 (t = 5.78)
# Rank 382: 'mean' feature #9484 (t = 5.78)
# Rank 383: 'max' feature #916 (t = 5.77)
# Rank 384: 'max' feature #12647 (t = 5.77)
# Rank 385: 'mean' feature #8132 (t = 5.77)
# Rank 386: 'max' feature #1406 (t = 5.77)
# Rank 387: 'mean' feature #14327 (t = 5.77)
# Rank 388: 'mean' feature #2021 (t = 5.77)
# Rank 389: 'mean' feature #11043 (t = 5.76)
# Rank 390: 'mean' feature #6572 (t = 5.76)
# Rank 391: 'max' feature #6211 (t = 5.75)
# Rank 392: 'max' feature #9900 (t = 5.75)
# Rank 393: 'mean' feature #2442 (t = 5.74)
# Rank 394: 'max' feature #6570 (t = 5.73)
# Rank 395: 'mean' feature #9833 (t = 5.73)
# Rank 396: 'mean' feature #4465 (t = 5.72)
# Rank 397: 'max' feature #12193 (t = 5.72)
# Rank 398: 'max' feature #12735 (t = 5.72)
# Rank 399: 'max' feature #12576 (t = 5.71)
# Rank 400: 'max' feature #10733 (t = 5.71)
# Rank 401: 'mean' feature #16303 (t = 5.71)
# Rank 402: 'mean' feature #2399 (t = 5.70)
# Rank 403: 'mean' feature #3174 (t = 5.70)
# Rank 404: 'max' feature #6000 (t = 5.70)
# Rank 405: 'mean' feature #6566 (t = 5.70)
# Rank 406: 'mean' feature #3808 (t = 5.69)
# Rank 407: 'max' feature #10266 (t = 5.69)
# Rank 408: 'max' feature #12663 (t = 5.69)
# Rank 409: 'max' feature #615 (t = 5.68)
# Rank 410: 'mean' feature #11049 (t = 5.68)
# Rank 411: 'mean' feature #97 (t = 5.68)
# Rank 412: 'mean' feature #13882 (t = 5.68)
# Rank 413: 'max' feature #2925 (t = 5.68)
# Rank 414: 'max' feature #15574 (t = 5.67)
# Rank 415: 'mean' feature #2819 (t = 5.67)
# Rank 416: 'mean' feature #12814 (t = 5.66)
# Rank 417: 'mean' feature #1988 (t = 5.66)
# Rank 418: 'mean' feature #2616 (t = 5.66)
# Rank 419: 'max' feature #13882 (t = 5.66)
# Rank 420: 'mean' feature #4838 (t = 5.65)
# Rank 421: 'mean' feature #14255 (t = 5.65)
# Rank 422: 'mean' feature #13963 (t = 5.65)
# Rank 423: 'mean' feature #12178 (t = 5.64)
# Rank 424: 'max' feature #3749 (t = 5.64)
# Rank 425: 'max' feature #110 (t = 5.63)
# Rank 426: 'mean' feature #5041 (t = 5.63)
# Rank 427: 'mean' feature #1739 (t = 5.62)
# Rank 428: 'max' feature #15441 (t = 5.62)
# Rank 429: 'mean' feature #9288 (t = 5.61)
# Rank 430: 'mean' feature #3101 (t = 5.61)
# Rank 431: 'max' feature #9311 (t = 5.61)
# Rank 432: 'max' feature #11240 (t = 5.60)
# Rank 433: 'mean' feature #939 (t = 5.60)
# Rank 434: 'max' feature #8268 (t = 5.60)
# Rank 435: 'mean' feature #4195 (t = 5.59)
# Rank 436: 'mean' feature #14772 (t = 5.59)
# Rank 437: 'mean' feature #11103 (t = 5.59)
# Rank 438: 'mean' feature #9088 (t = 5.59)
# Rank 439: 'max' feature #8732 (t = 5.58)
# Rank 440: 'mean' feature #16204 (t = 5.58)
# Rank 441: 'mean' feature #1381 (t = 5.58)
# Rank 442: 'mean' feature #8776 (t = 5.58)
# Rank 443: 'mean' feature #5323 (t = 5.57)
# Rank 444: 'mean' feature #15262 (t = 5.57)
# Rank 445: 'mean' feature #14844 (t = 5.57)
# Rank 446: 'mean' feature #10538 (t = 5.57)
# Rank 447: 'mean' feature #9930 (t = 5.56)
# Rank 448: 'max' feature #6254 (t = 5.56)
# Rank 449: 'mean' feature #3375 (t = 5.56)
# Rank 450: 'max' feature #14000 (t = 5.56)
# Rank 451: 'max' feature #10117 (t = 5.55)
# Rank 452: 'mean' feature #13970 (t = 5.55)
# Rank 453: 'mean' feature #9502 (t = 5.54)
# Rank 454: 'max' feature #8411 (t = 5.54)
# Rank 455: 'max' feature #3624 (t = 5.54)
# Rank 456: 'mean' feature #3874 (t = 5.53)
# Rank 457: 'mean' feature #8384 (t = 5.52)
# Rank 458: 'mean' feature #5240 (t = 5.52)
# Rank 459: 'mean' feature #7097 (t = 5.51)
# Rank 460: 'max' feature #11461 (t = 5.51)
# Rank 461: 'mean' feature #11552 (t = 5.51)
# Rank 462: 'mean' feature #6947 (t = 5.50)
# Rank 463: 'mean' feature #3157 (t = 5.50)
# Rank 464: 'mean' feature #8080 (t = 5.50)
# Rank 465: 'max' feature #12021 (t = 5.48)
# Rank 466: 'mean' feature #7150 (t = 5.48)
# Rank 467: 'max' feature #10982 (t = 5.48)
# Rank 468: 'mean' feature #9990 (t = 5.48)
# Rank 469: 'mean' feature #5358 (t = 5.48)
# Rank 470: 'max' feature #14573 (t = 5.47)
# Rank 471: 'mean' feature #14540 (t = 5.47)
# Rank 472: 'mean' feature #1457 (t = 5.46)
# Rank 473: 'max' feature #11641 (t = 5.46)
# Rank 474: 'max' feature #7861 (t = 5.46)
# Rank 475: 'mean' feature #8113 (t = 5.46)
# Rank 476: 'max' feature #1704 (t = 5.45)
# Rank 477: 'max' feature #2319 (t = 5.45)
# Rank 478: 'mean' feature #3384 (t = 5.45)
# Rank 479: 'mean' feature #255 (t = 5.45)
# Rank 480: 'mean' feature #2505 (t = 5.44)
# Rank 481: 'max' feature #8333 (t = 5.44)
# Rank 482: 'max' feature #15821 (t = 5.44)
# Rank 483: 'max' feature #5078 (t = 5.44)
# Rank 484: 'max' feature #5230 (t = 5.44)
# Rank 485: 'mean' feature #1374 (t = 5.44)
# Rank 486: 'mean' feature #6486 (t = 5.43)
# Rank 487: 'mean' feature #3590 (t = 5.43)
# Rank 488: 'mean' feature #8667 (t = 5.43)
# Rank 489: 'mean' feature #2203 (t = 5.43)
# Rank 490: 'mean' feature #15557 (t = 5.43)
# Rank 491: 'max' feature #5317 (t = 5.42)
# Rank 492: 'mean' feature #16290 (t = 5.42)
# Rank 493: 'mean' feature #4600 (t = 5.42)
# Rank 494: 'mean' feature #8570 (t = 5.41)
# Rank 495: 'mean' feature #11400 (t = 5.40)
# Rank 496: 'max' feature #4418 (t = 5.40)
# Rank 497: 'max' feature #11262 (t = 5.40)
# Rank 498: 'max' feature #4152 (t = 5.40)
# Rank 499: 'mean' feature #3500 (t = 5.40)
# Rank 500: 'mean' feature #8063 (t = 5.39)
# Rank 501: 'max' feature #294 (t = 5.39)
# Rank 502: 'max' feature #585 (t = 5.39)
# Rank 503: 'mean' feature #159 (t = 5.38)
# Rank 504: 'max' feature #15453 (t = 5.38)
# Rank 505: 'mean' feature #8817 (t = 5.38)
# Rank 506: 'mean' feature #13646 (t = 5.38)
# Rank 507: 'mean' feature #11393 (t = 5.38)
# Rank 508: 'mean' feature #14751 (t = 5.38)
# Rank 509: 'max' feature #1092 (t = 5.37)
# Rank 510: 'max' feature #945 (t = 5.37)
# Rank 511: 'max' feature #9512 (t = 5.36)
# Rank 512: 'max' feature #8570 (t = 5.36)
# Rank 513: 'max' feature #979 (t = 5.36)
# Rank 514: 'max' feature #7112 (t = 5.36)
# Rank 515: 'mean' feature #2133 (t = 5.36)
# Rank 516: 'mean' feature #10740 (t = 5.36)
# Rank 517: 'mean' feature #13784 (t = 5.35)
# Rank 518: 'max' feature #8022 (t = 5.35)
# Rank 519: 'mean' feature #1871 (t = 5.35)
# Rank 520: 'max' feature #10618 (t = 5.34)
# Rank 521: 'mean' feature #8121 (t = 5.34)
# Rank 522: 'mean' feature #12499 (t = 5.34)
# Rank 523: 'mean' feature #4385 (t = 5.34)
# Rank 524: 'mean' feature #9238 (t = 5.33)
# Rank 525: 'max' feature #8482 (t = 5.33)
# Rank 526: 'mean' feature #3604 (t = 5.33)
# Rank 527: 'mean' feature #4206 (t = 5.33)
# Rank 528: 'mean' feature #12412 (t = 5.33)
# Rank 529: 'mean' feature #7685 (t = 5.33)
# Rank 530: 'mean' feature #3833 (t = 5.33)
# Rank 531: 'mean' feature #14324 (t = 5.33)
# Rank 532: 'max' feature #16116 (t = 5.33)
# Rank 533: 'mean' feature #12187 (t = 5.33)
# Rank 534: 'mean' feature #13075 (t = 5.32)
# Rank 535: 'max' feature #12909 (t = 5.32)
# Rank 536: 'mean' feature #7184 (t = 5.32)
# Rank 537: 'max' feature #12595 (t = 5.32)
# Rank 538: 'mean' feature #13059 (t = 5.32)
# Rank 539: 'mean' feature #5553 (t = 5.31)
# Rank 540: 'max' feature #16022 (t = 5.31)
# Rank 541: 'mean' feature #13398 (t = 5.31)
# Rank 542: 'max' feature #5370 (t = 5.31)
# Rank 543: 'max' feature #4075 (t = 5.31)
# Rank 544: 'mean' feature #5375 (t = 5.30)
# Rank 545: 'max' feature #9979 (t = 5.30)
# Rank 546: 'mean' feature #1720 (t = 5.30)
# Rank 547: 'max' feature #7522 (t = 5.29)
# Rank 548: 'mean' feature #10618 (t = 5.29)
# Rank 549: 'mean' feature #13912 (t = 5.29)
# Rank 550: 'mean' feature #1233 (t = 5.29)
# Rank 551: 'max' feature #3820 (t = 5.29)
# Rank 552: 'mean' feature #3609 (t = 5.29)
# Rank 553: 'mean' feature #12862 (t = 5.29)
# Rank 554: 'max' feature #2798 (t = 5.28)
# Rank 555: 'mean' feature #13064 (t = 5.28)
# Rank 556: 'mean' feature #7452 (t = 5.28)
# Rank 557: 'max' feature #10846 (t = 5.27)
# Rank 558: 'mean' feature #5408 (t = 5.26)
# Rank 559: 'mean' feature #9149 (t = 5.26)
# Rank 560: 'mean' feature #4842 (t = 5.26)
# Rank 561: 'mean' feature #4604 (t = 5.26)
# Rank 562: 'max' feature #5448 (t = 5.26)
# Rank 563: 'max' feature #6470 (t = 5.26)
# Rank 564: 'mean' feature #5272 (t = 5.26)
# Rank 565: 'max' feature #5752 (t = 5.25)
# Rank 566: 'mean' feature #4247 (t = 5.25)
# Rank 567: 'mean' feature #615 (t = 5.25)
# Rank 568: 'mean' feature #7550 (t = 5.25)
# Rank 569: 'mean' feature #15762 (t = 5.25)
# Rank 570: 'max' feature #14608 (t = 5.24)
# Rank 571: 'mean' feature #9678 (t = 5.24)
# Rank 572: 'mean' feature #6451 (t = 5.24)
# Rank 573: 'max' feature #9521 (t = 5.23)
# Rank 574: 'max' feature #1345 (t = 5.23)
# Rank 575: 'mean' feature #13358 (t = 5.23)
# Rank 576: 'mean' feature #12397 (t = 5.22)
# Rank 577: 'mean' feature #13889 (t = 5.22)
# Rank 578: 'mean' feature #3471 (t = 5.22)
# Rank 579: 'max' feature #6448 (t = 5.22)
# Rank 580: 'max' feature #1016 (t = 5.21)
# Rank 581: 'max' feature #1074 (t = 5.21)
# Rank 582: 'max' feature #5612 (t = 5.21)
# Rank 583: 'max' feature #2310 (t = 5.21)
# Rank 584: 'max' feature #6141 (t = 5.20)
# Rank 585: 'mean' feature #963 (t = 5.20)
# Rank 586: 'mean' feature #8832 (t = 5.20)
# Rank 587: 'mean' feature #10656 (t = 5.20)
# Rank 588: 'max' feature #2542 (t = 5.20)
# Rank 589: 'mean' feature #15475 (t = 5.20)
# Rank 590: 'mean' feature #6790 (t = 5.20)
# Rank 591: 'mean' feature #325 (t = 5.20)
# Rank 592: 'mean' feature #8877 (t = 5.19)
# Rank 593: 'max' feature #5142 (t = 5.19)
# Rank 594: 'mean' feature #1922 (t = 5.19)
# Rank 595: 'mean' feature #15800 (t = 5.19)
# Rank 596: 'max' feature #12868 (t = 5.19)
# Rank 597: 'max' feature #12350 (t = 5.19)
# Rank 598: 'max' feature #8968 (t = 5.18)
# Rank 599: 'mean' feature #3494 (t = 5.18)
# Rank 600: 'max' feature #11125 (t = 5.18)
# Rank 601: 'max' feature #13334 (t = 5.18)
# Rank 602: 'max' feature #10113 (t = 5.17)
# Rank 603: 'mean' feature #2871 (t = 5.17)
# Rank 604: 'max' feature #12228 (t = 5.17)
# Rank 605: 'mean' feature #1215 (t = 5.17)
# Rank 606: 'max' feature #6486 (t = 5.17)
# Rank 607: 'mean' feature #16148 (t = 5.17)
# Rank 608: 'max' feature #4264 (t = 5.16)
# Rank 609: 'max' feature #13685 (t = 5.16)
# Rank 610: 'mean' feature #12496 (t = 5.16)
# Rank 611: 'mean' feature #13181 (t = 5.16)
# Rank 612: 'max' feature #5867 (t = 5.16)
# Rank 613: 'mean' feature #5647 (t = 5.16)
# Rank 614: 'mean' feature #6100 (t = 5.16)
# Rank 615: 'max' feature #1051 (t = 5.16)
# Rank 616: 'max' feature #10455 (t = 5.15)
# Rank 617: 'max' feature #9162 (t = 5.15)
# Rank 618: 'mean' feature #12791 (t = 5.15)
# Rank 619: 'max' feature #3990 (t = 5.14)
# Rank 620: 'mean' feature #15788 (t = 5.14)
# Rank 621: 'max' feature #13926 (t = 5.14)
# Rank 622: 'mean' feature #9289 (t = 5.14)
# Rank 623: 'mean' feature #13602 (t = 5.13)
# Rank 624: 'mean' feature #13659 (t = 5.13)
# Rank 625: 'max' feature #9118 (t = 5.13)
# Rank 626: 'max' feature #11397 (t = 5.13)
# Rank 627: 'mean' feature #2591 (t = 5.13)
# Rank 628: 'mean' feature #5780 (t = 5.13)
# Rank 629: 'mean' feature #1700 (t = 5.13)
# Rank 630: 'mean' feature #5046 (t = 5.13)
# Rank 631: 'max' feature #10421 (t = 5.13)
# Rank 632: 'mean' feature #1007 (t = 5.13)
# Rank 633: 'mean' feature #9118 (t = 5.13)
# Rank 634: 'mean' feature #12107 (t = 5.12)
# Rank 635: 'max' feature #7977 (t = 5.12)
# Rank 636: 'max' feature #5767 (t = 5.12)
# Rank 637: 'max' feature #12209 (t = 5.12)
# Rank 638: 'max' feature #7685 (t = 5.12)
# Rank 639: 'max' feature #10769 (t = 5.12)
# Rank 640: 'max' feature #1462 (t = 5.12)
# Rank 641: 'max' feature #11633 (t = 5.11)
# Rank 642: 'mean' feature #15896 (t = 5.11)
# Rank 643: 'mean' feature #3477 (t = 5.11)
# Rank 644: 'mean' feature #31 (t = 5.11)
# Rank 645: 'mean' feature #10879 (t = 5.11)
# Rank 646: 'mean' feature #9122 (t = 5.11)
# Rank 647: 'mean' feature #13291 (t = 5.10)
# Rank 648: 'mean' feature #8171 (t = 5.10)
# Rank 649: 'max' feature #9930 (t = 5.10)
# Rank 650: 'mean' feature #10354 (t = 5.10)
# Rank 651: 'mean' feature #4612 (t = 5.10)
# Rank 652: 'max' feature #12133 (t = 5.10)
# Rank 653: 'max' feature #8413 (t = 5.09)
# Rank 654: 'mean' feature #14032 (t = 5.09)
# Rank 655: 'max' feature #4007 (t = 5.09)
# Rank 656: 'max' feature #15783 (t = 5.09)
# Rank 657: 'mean' feature #4531 (t = 5.09)
# Rank 658: 'max' feature #1640 (t = 5.09)
# Rank 659: 'mean' feature #1406 (t = 5.09)
# Rank 660: 'mean' feature #4558 (t = 5.08)
# Rank 661: 'max' feature #5289 (t = 5.08)
# Rank 662: 'max' feature #14161 (t = 5.08)
# Rank 663: 'mean' feature #2012 (t = 5.08)
# Rank 664: 'mean' feature #261 (t = 5.08)
# Rank 665: 'max' feature #6802 (t = 5.08)
# Rank 666: 'max' feature #4221 (t = 5.08)
# Rank 667: 'mean' feature #11641 (t = 5.07)
# Rank 668: 'max' feature #13784 (t = 5.07)
# Rank 669: 'max' feature #7335 (t = 5.07)
# Rank 670: 'mean' feature #11235 (t = 5.07)
# Rank 671: 'mean' feature #3752 (t = 5.07)
# Rank 672: 'mean' feature #6395 (t = 5.07)
# Rank 673: 'max' feature #4564 (t = 5.07)
# Rank 674: 'mean' feature #2131 (t = 5.07)
# Rank 675: 'max' feature #13181 (t = 5.06)
# Rank 676: 'max' feature #12497 (t = 5.06)
# Rank 677: 'mean' feature #13334 (t = 5.06)
# Rank 678: 'mean' feature #1097 (t = 5.06)
# Rank 679: 'mean' feature #7587 (t = 5.05)
# Rank 680: 'max' feature #3078 (t = 5.05)
# Rank 681: 'mean' feature #14161 (t = 5.05)
# Rank 682: 'mean' feature #7722 (t = 5.05)
# Rank 683: 'max' feature #14129 (t = 5.05)
# Rank 684: 'max' feature #1090 (t = 5.05)
# Rank 685: 'max' feature #2442 (t = 5.05)
# Rank 686: 'mean' feature #14349 (t = 5.05)
# Rank 687: 'max' feature #10193 (t = 5.04)
# Rank 688: 'mean' feature #6430 (t = 5.04)
# Rank 689: 'max' feature #2813 (t = 5.04)
# Rank 690: 'mean' feature #10495 (t = 5.04)
# Rank 691: 'max' feature #12717 (t = 5.03)
# Rank 692: 'mean' feature #511 (t = 5.03)
# Rank 693: 'mean' feature #13526 (t = 5.03)
# Rank 694: 'mean' feature #3366 (t = 5.03)
# Rank 695: 'mean' feature #16039 (t = 5.03)
# Rank 696: 'max' feature #3534 (t = 5.02)
# Rank 697: 'mean' feature #2779 (t = 5.02)
# Rank 698: 'mean' feature #11633 (t = 5.02)
# Rank 699: 'mean' feature #13637 (t = 5.02)
# Rank 700: 'mean' feature #1789 (t = 5.02)
# Rank 701: 'max' feature #5523 (t = 5.02)
# Rank 702: 'max' feature #8122 (t = 5.01)
# Rank 703: 'max' feature #4964 (t = 5.01)
# Rank 704: 'max' feature #3375 (t = 5.01)
# Rank 705: 'max' feature #7274 (t = 5.01)
# Rank 706: 'mean' feature #15441 (t = 5.01)
# Rank 707: 'mean' feature #6410 (t = 5.01)
# Rank 708: 'mean' feature #2678 (t = 5.01)
# Rank 709: 'mean' feature #1863 (t = 5.01)
# Rank 710: 'mean' feature #12969 (t = 5.01)
# Rank 711: 'max' feature #13698 (t = 5.00)
# Rank 712: 'max' feature #5817 (t = 5.00)
# Rank 713: 'max' feature #15126 (t = 5.00)
# Rank 714: 'mean' feature #4736 (t = 5.00)
# Rank 715: 'mean' feature #9919 (t = 5.00)
# Rank 716: 'mean' feature #11136 (t = 5.00)
# Rank 717: 'mean' feature #1405 (t = 5.00)
# Rank 718: 'mean' feature #8732 (t = 5.00)
# Rank 719: 'mean' feature #3507 (t = 5.00)
# Rank 720: 'max' feature #9036 (t = 4.99)
# Rank 721: 'max' feature #4655 (t = 4.99)
# Rank 722: 'mean' feature #13978 (t = 4.99)
# Rank 723: 'max' feature #3082 (t = 4.99)
# Rank 724: 'max' feature #14429 (t = 4.99)
# Rank 725: 'mean' feature #9738 (t = 4.98)
# Rank 726: 'mean' feature #15492 (t = 4.98)
# Rank 727: 'mean' feature #14137 (t = 4.98)
# Rank 728: 'mean' feature #2617 (t = 4.98)
# Rank 729: 'mean' feature #11587 (t = 4.98)
# Rank 730: 'mean' feature #7245 (t = 4.97)
# Rank 731: 'max' feature #8436 (t = 4.97)
# Rank 732: 'max' feature #11282 (t = 4.97)
# Rank 733: 'mean' feature #5652 (t = 4.97)
# Rank 734: 'mean' feature #10570 (t = 4.97)
# Rank 735: 'mean' feature #850 (t = 4.97)
# Rank 736: 'mean' feature #88 (t = 4.97)
# Rank 737: 'max' feature #9454 (t = 4.97)
# Rank 738: 'mean' feature #12595 (t = 4.97)
# Rank 739: 'max' feature #4988 (t = 4.97)
# Rank 740: 'max' feature #1562 (t = 4.97)
# Rank 741: 'mean' feature #10193 (t = 4.96)
# Rank 742: 'max' feature #15747 (t = 4.95)
# Rank 743: 'max' feature #11578 (t = 4.95)
# Rank 744: 'mean' feature #1794 (t = 4.95)
# Rank 745: 'max' feature #4604 (t = 4.95)
# Rank 746: 'mean' feature #14650 (t = 4.95)
# Rank 747: 'mean' feature #14407 (t = 4.95)
# Rank 748: 'mean' feature #14244 (t = 4.94)
# Rank 749: 'max' feature #14137 (t = 4.94)
# Rank 750: 'max' feature #3471 (t = 4.94)
# Rank 751: 'max' feature #2505 (t = 4.94)
# Rank 752: 'max' feature #6889 (t = 4.94)
# Rank 753: 'mean' feature #635 (t = 4.94)
# Rank 754: 'max' feature #4838 (t = 4.94)
# Rank 755: 'max' feature #5231 (t = 4.93)
# Rank 756: 'mean' feature #12042 (t = 4.93)
# Rank 757: 'mean' feature #512 (t = 4.93)
# Rank 758: 'mean' feature #4023 (t = 4.93)
# Rank 759: 'mean' feature #1399 (t = 4.93)
# Rank 760: 'mean' feature #2807 (t = 4.93)
# Rank 761: 'mean' feature #11195 (t = 4.93)
# Rank 762: 'max' feature #13877 (t = 4.92)
# Rank 763: 'mean' feature #5841 (t = 4.92)
# Rank 764: 'max' feature #10417 (t = 4.92)
# Rank 765: 'mean' feature #1333 (t = 4.92)
# Rank 766: 'max' feature #14650 (t = 4.92)
# Rank 767: 'mean' feature #12041 (t = 4.92)
# Rank 768: 'mean' feature #2725 (t = 4.92)
# Rank 769: 'max' feature #13657 (t = 4.92)
# Rank 770: 'max' feature #8121 (t = 4.92)
# Rank 771: 'max' feature #8943 (t = 4.92)
# Rank 772: 'max' feature #6654 (t = 4.92)
# Rank 773: 'mean' feature #4543 (t = 4.92)
# Rank 774: 'mean' feature #9538 (t = 4.91)
# Rank 775: 'max' feature #9205 (t = 4.91)
# Rank 776: 'max' feature #6237 (t = 4.91)
# Rank 777: 'mean' feature #266 (t = 4.91)
# Rank 778: 'mean' feature #979 (t = 4.90)
# Rank 779: 'mean' feature #15815 (t = 4.90)
# Rank 780: 'mean' feature #9319 (t = 4.90)
# Rank 781: 'max' feature #12309 (t = 4.90)
# Rank 782: 'max' feature #1700 (t = 4.90)
# Rank 783: 'mean' feature #12576 (t = 4.90)
# Rank 784: 'mean' feature #13847 (t = 4.90)
# Rank 785: 'max' feature #9164 (t = 4.89)
# Rank 786: 'mean' feature #9218 (t = 4.89)
# Rank 787: 'mean' feature #62 (t = 4.89)
# Rank 788: 'mean' feature #11397 (t = 4.89)
# Rank 789: 'mean' feature #215 (t = 4.89)
# Rank 790: 'mean' feature #1159 (t = 4.89)
# Rank 791: 'mean' feature #12214 (t = 4.88)
# Rank 792: 'mean' feature #2790 (t = 4.88)
# Rank 793: 'mean' feature #4546 (t = 4.88)
# Rank 794: 'max' feature #5143 (t = 4.88)
# Rank 795: 'mean' feature #3321 (t = 4.88)
# Rank 796: 'mean' feature #3746 (t = 4.88)
# Rank 797: 'mean' feature #15206 (t = 4.88)
# Rank 798: 'mean' feature #9059 (t = 4.88)
# Rank 799: 'mean' feature #3749 (t = 4.88)
# Rank 800: 'mean' feature #3093 (t = 4.88)
# Rank 801: 'mean' feature #13497 (t = 4.87)
# Rank 802: 'mean' feature #11324 (t = 4.87)
# Rank 803: 'max' feature #3718 (t = 4.87)
# Rank 804: 'mean' feature #13549 (t = 4.87)
# Rank 805: 'max' feature #2702 (t = 4.87)
# Rank 806: 'mean' feature #2340 (t = 4.87)
# Rank 807: 'mean' feature #15709 (t = 4.87)
# Rank 808: 'mean' feature #2712 (t = 4.87)
# Rank 809: 'mean' feature #5482 (t = 4.87)
# Rank 810: 'mean' feature #3957 (t = 4.87)
# Rank 811: 'mean' feature #1645 (t = 4.86)
# Rank 812: 'mean' feature #12909 (t = 4.86)
# Rank 813: 'mean' feature #125 (t = 4.86)
# Rank 814: 'mean' feature #3493 (t = 4.86)
# Rank 815: 'mean' feature #11017 (t = 4.86)
# Rank 816: 'max' feature #5250 (t = 4.86)
# Rank 817: 'mean' feature #5144 (t = 4.86)
# Rank 818: 'max' feature #15254 (t = 4.86)
# Rank 819: 'max' feature #13228 (t = 4.86)
# Rank 820: 'max' feature #15005 (t = 4.85)
# Rank 821: 'max' feature #3758 (t = 4.85)
# Rank 822: 'mean' feature #3514 (t = 4.85)
# Rank 823: 'max' feature #2325 (t = 4.85)
# Rank 824: 'mean' feature #7112 (t = 4.85)
# Rank 825: 'mean' feature #15778 (t = 4.85)
# Rank 826: 'max' feature #2021 (t = 4.85)
# Rank 827: 'mean' feature #13003 (t = 4.85)
# Rank 828: 'max' feature #12777 (t = 4.85)
# Rank 829: 'mean' feature #11733 (t = 4.85)
# Rank 830: 'max' feature #3625 (t = 4.84)
# Rank 831: 'mean' feature #10497 (t = 4.84)
# Rank 832: 'max' feature #2628 (t = 4.84)
# Rank 833: 'mean' feature #3126 (t = 4.83)
# Rank 834: 'mean' feature #2236 (t = 4.83)
# Rank 835: 'max' feature #1988 (t = 4.83)
# Rank 836: 'mean' feature #13727 (t = 4.83)
# Rank 837: 'max' feature #12013 (t = 4.83)
# Rank 838: 'mean' feature #9908 (t = 4.83)
# Rank 839: 'max' feature #8063 (t = 4.82)
# Rank 840: 'mean' feature #2612 (t = 4.82)
# Rank 841: 'max' feature #10223 (t = 4.82)
# Rank 842: 'mean' feature #5776 (t = 4.82)
# Rank 843: 'max' feature #11448 (t = 4.82)
# Rank 844: 'max' feature #16331 (t = 4.82)
# Rank 845: 'mean' feature #13511 (t = 4.82)
# Rank 846: 'mean' feature #12724 (t = 4.82)
# Rank 847: 'max' feature #9493 (t = 4.82)
# Rank 848: 'max' feature #9039 (t = 4.82)
# Rank 849: 'mean' feature #12942 (t = 4.82)
# Rank 850: 'max' feature #11297 (t = 4.82)
# Rank 851: 'max' feature #4668 (t = 4.82)
# Rank 852: 'mean' feature #1664 (t = 4.82)
# Rank 853: 'max' feature #8300 (t = 4.81)
# Rank 854: 'mean' feature #15145 (t = 4.81)
# Rank 855: 'mean' feature #15433 (t = 4.81)
# Rank 856: 'max' feature #3982 (t = 4.81)
# Rank 857: 'mean' feature #2735 (t = 4.81)
# Rank 858: 'mean' feature #13473 (t = 4.81)
# Rank 859: 'max' feature #13020 (t = 4.81)
# Rank 860: 'max' feature #13395 (t = 4.81)
# Rank 861: 'max' feature #4283 (t = 4.81)
# Rank 862: 'mean' feature #13896 (t = 4.80)
# Rank 863: 'mean' feature #15251 (t = 4.80)
# Rank 864: 'mean' feature #2003 (t = 4.80)
# Rank 865: 'max' feature #4550 (t = 4.80)
# Rank 866: 'max' feature #10720 (t = 4.80)
# Rank 867: 'max' feature #15815 (t = 4.80)
# Rank 868: 'max' feature #4502 (t = 4.80)
# Rank 869: 'mean' feature #11773 (t = 4.79)
# Rank 870: 'mean' feature #16252 (t = 4.79)
# Rank 871: 'max' feature #13753 (t = 4.79)
# Rank 872: 'mean' feature #5930 (t = 4.79)
# Rank 873: 'mean' feature #10390 (t = 4.79)
# Rank 874: 'max' feature #15695 (t = 4.79)
# Rank 875: 'mean' feature #5990 (t = 4.79)
# Rank 876: 'max' feature #676 (t = 4.79)
# Rank 877: 'mean' feature #2041 (t = 4.78)
# Rank 878: 'max' feature #416 (t = 4.78)
# Rank 879: 'mean' feature #1640 (t = 4.78)
# Rank 880: 'mean' feature #13263 (t = 4.78)
# Rank 881: 'max' feature #13106 (t = 4.78)
# Rank 882: 'mean' feature #9657 (t = 4.78)
# Rank 883: 'mean' feature #12149 (t = 4.77)
# Rank 884: 'max' feature #249 (t = 4.77)
# Rank 885: 'mean' feature #12176 (t = 4.77)
# Rank 886: 'mean' feature #2182 (t = 4.77)
# Rank 887: 'max' feature #16012 (t = 4.77)
# Rank 888: 'max' feature #11269 (t = 4.77)
# Rank 889: 'mean' feature #1090 (t = 4.77)
# Rank 890: 'mean' feature #15751 (t = 4.76)
# Rank 891: 'mean' feature #9600 (t = 4.76)
# Rank 892: 'mean' feature #12629 (t = 4.76)
# Rank 893: 'max' feature #10002 (t = 4.76)
# Rank 894: 'mean' feature #7171 (t = 4.76)
# Rank 895: 'mean' feature #13641 (t = 4.76)
# Rank 896: 'mean' feature #3785 (t = 4.75)
# Rank 897: 'max' feature #3366 (t = 4.75)
# Rank 898: 'max' feature #723 (t = 4.75)
# Rank 899: 'mean' feature #1516 (t = 4.75)
# Rank 900: 'mean' feature #6290 (t = 4.75)
# Rank 901: 'mean' feature #1051 (t = 4.75)
# Rank 902: 'mean' feature #10792 (t = 4.74)
# Rank 903: 'mean' feature #3694 (t = 4.74)
# Rank 904: 'mean' feature #4272 (t = 4.74)
# Rank 905: 'max' feature #12515 (t = 4.74)
# Rank 906: 'mean' feature #3565 (t = 4.74)
# Rank 907: 'max' feature #5273 (t = 4.74)
# Rank 908: 'max' feature #216 (t = 4.73)
# Rank 909: 'mean' feature #11205 (t = 4.73)
# Rank 910: 'max' feature #4842 (t = 4.73)
# Rank 911: 'max' feature #11212 (t = 4.73)
# Rank 912: 'mean' feature #9437 (t = 4.73)
# Rank 913: 'mean' feature #14412 (t = 4.73)
# Rank 914: 'mean' feature #5656 (t = 4.72)
# Rank 915: 'max' feature #938 (t = 4.72)
# Rank 916: 'mean' feature #15981 (t = 4.72)
# Rank 917: 'mean' feature #8798 (t = 4.72)
# Rank 918: 'max' feature #4206 (t = 4.72)
# Rank 919: 'max' feature #13494 (t = 4.72)
# Rank 920: 'max' feature #8877 (t = 4.72)
# Rank 921: 'mean' feature #14745 (t = 4.72)
# Rank 922: 'mean' feature #15824 (t = 4.72)
# Rank 923: 'max' feature #6935 (t = 4.72)
# Rank 924: 'mean' feature #11810 (t = 4.72)
# Rank 925: 'mean' feature #16370 (t = 4.71)
# Rank 926: 'mean' feature #14588 (t = 4.71)
# Rank 927: 'max' feature #6325 (t = 4.71)
# Rank 928: 'mean' feature #10459 (t = 4.71)
# Rank 929: 'mean' feature #2733 (t = 4.71)
# Rank 930: 'max' feature #88 (t = 4.71)
# Rank 931: 'mean' feature #14429 (t = 4.70)
# Rank 932: 'mean' feature #2770 (t = 4.70)
# Rank 933: 'max' feature #13948 (t = 4.70)
# Rank 934: 'max' feature #11552 (t = 4.70)
# Rank 935: 'mean' feature #9017 (t = 4.70)
# Rank 936: 'max' feature #9595 (t = 4.69)
# Rank 937: 'mean' feature #15648 (t = 4.69)
# Rank 938: 'max' feature #5746 (t = 4.69)
# Rank 939: 'max' feature #11324 (t = 4.69)
# Rank 940: 'mean' feature #5317 (t = 4.69)
# Rank 941: 'max' feature #4948 (t = 4.69)
# Rank 942: 'mean' feature #3438 (t = 4.69)
# Rank 943: 'max' feature #62 (t = 4.69)
# Rank 944: 'mean' feature #7938 (t = 4.69)
# Rank 945: 'mean' feature #1045 (t = 4.69)
# Rank 946: 'max' feature #1180 (t = 4.69)
# Rank 947: 'mean' feature #5289 (t = 4.68)
# Rank 948: 'mean' feature #11208 (t = 4.68)
# Rank 949: 'mean' feature #7418 (t = 4.68)
# Rank 950: 'mean' feature #12213 (t = 4.68)
# Rank 951: 'max' feature #14663 (t = 4.68)
# Rank 952: 'mean' feature #13808 (t = 4.68)
# Rank 953: 'mean' feature #3142 (t = 4.68)
# Rank 954: 'mean' feature #12209 (t = 4.68)
# Rank 955: 'mean' feature #2971 (t = 4.68)
# Rank 956: 'mean' feature #6027 (t = 4.68)
# Rank 957: 'mean' feature #14816 (t = 4.67)
# Rank 958: 'max' feature #13782 (t = 4.67)
# Rank 959: 'mean' feature #1881 (t = 4.67)
# Rank 960: 'mean' feature #4149 (t = 4.67)
# Rank 961: 'max' feature #2004 (t = 4.67)
# Rank 962: 'mean' feature #7504 (t = 4.67)
# Rank 963: 'max' feature #10108 (t = 4.67)
# Rank 964: 'max' feature #13972 (t = 4.67)
# Rank 965: 'mean' feature #168 (t = 4.67)
# Rank 966: 'max' feature #9163 (t = 4.67)
# Rank 967: 'mean' feature #4512 (t = 4.66)
# Rank 968: 'mean' feature #3270 (t = 4.66)
# Rank 969: 'mean' feature #15528 (t = 4.66)
# Rank 970: 'mean' feature #5793 (t = 4.66)
# Rank 971: 'max' feature #12314 (t = 4.66)
# Rank 972: 'max' feature #10487 (t = 4.66)
# Rank 973: 'mean' feature #13613 (t = 4.66)
# Rank 974: 'mean' feature #284 (t = 4.66)
# Rank 975: 'max' feature #2340 (t = 4.66)
# Rank 976: 'max' feature #6058 (t = 4.66)
# Rank 977: 'mean' feature #6117 (t = 4.66)
# Rank 978: 'mean' feature #3679 (t = 4.65)
# Rank 979: 'mean' feature #945 (t = 4.65)
# Rank 980: 'max' feature #2591 (t = 4.65)
# Rank 981: 'mean' feature #66 (t = 4.65)
# Rank 982: 'mean' feature #13388 (t = 4.64)
# Rank 983: 'max' feature #13824 (t = 4.64)
# Rank 984: 'mean' feature #10679 (t = 4.64)
# Rank 985: 'mean' feature #13606 (t = 4.64)
# Rank 986: 'max' feature #4688 (t = 4.63)
# Rank 987: 'mean' feature #5998 (t = 4.63)
# Rank 988: 'max' feature #540 (t = 4.63)
# Rank 989: 'mean' feature #6650 (t = 4.63)
# Rank 990: 'mean' feature #1430 (t = 4.63)
# Rank 991: 'mean' feature #10759 (t = 4.63)
# Rank 992: 'max' feature #4543 (t = 4.62)
# Rank 993: 'mean' feature #14430 (t = 4.62)
# Rank 994: 'max' feature #13947 (t = 4.62)
# Rank 995: 'max' feature #13076 (t = 4.62)
# Rank 996: 'mean' feature #9929 (t = 4.62)
# Rank 997: 'mean' feature #646 (t = 4.62)
# Rank 998: 'mean' feature #12320 (t = 4.62)
# Rank 999: 'mean' feature #3917 (t = 4.62)
# Rank 1000: 'max' feature #5234 (t = 4.62)
# /tmp/ipykernel_262644/2659828760.py:10: RuntimeWarning: invalid value encountered in divide
#   t_stats = np.abs((X_pos.mean(0) - X_neg.mean(0)) /

# %%
top_idx = ranked_idx[:1000]
X_top = Xc[:, top_idx]      

# 4) Split into train/test
X_train, X_test, y_train, y_test = train_test_split(
    X_top, y, stratify=y, test_size=0.2, random_state=42
)

# %%
# 5) Train with L1 logistic regression & balanced class weights
clf = make_pipeline(
    StandardScaler(),
    LogisticRegression(
        penalty="l1",
        solver="saga",
        # class_weight="balanced",
        C=1.0,
        max_iter=2000,
        random_state=42
    )
)
clf.fit(X_train, y_train)
clf.fit(X_train, y_train)

# 6) Evaluate
y_pred   = clf.predict(X_test)
y_probs  = clf.predict_proba(X_test)[:,1]

print(classification_report(y_test, y_pred))
print("ROC AUC:", roc_auc_score(y_test, y_probs))

# 7) Inspect which of your top-1000 actually got nonzero weights
lr = clf.named_steps["logisticregression"]
coefs = lr.coef_.ravel()
nz    = np.where(coefs != 0)[0]

print(f"\nOut of your 1000 features, {len(nz)} have nonzero weight.")
print("Nonzero feature indices (within the top-1000 list):", nz)

# %%
param_grid = {"logisticregression__C": [0.01, 0.1, 1, 10, 100]}

pipeline = make_pipeline(
    StandardScaler(),
    LogisticRegression(
        penalty="l2",
        solver="saga",         
        class_weight="balanced",
        max_iter=2000,
        random_state=42
    )
)

search = GridSearchCV(
    pipeline,
    param_grid,
    cv=5,
    scoring="roc_auc",
    n_jobs=-1,
    verbose=1
)
search.fit(X_train, y_train)

print("Best C (inverse reg. strength):", search.best_params_["logisticregression__C"])
print("CV ROC AUC:", search.best_score_)


best_clf = search.best_estimator_
y_pred_probs = best_clf.predict_proba(X_test)[:, 1]
y_pred       = best_clf.predict(X_test)

print(classification_report(y_test, y_pred))
print("Test ROC AUC:", roc_auc_score(y_test, y_pred_probs))
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# /home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/airlay88/surprise_sae/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Best C (inverse reg. strength): 0.01
# CV ROC AUC: 0.6935088208936653
#               precision    recall  f1-score   support
#
#            0       0.34      0.58      0.43       248
#            1       0.86      0.70      0.77       939
#
#     accuracy                           0.67      1187
#    macro avg       0.60      0.64      0.60      1187
# weighted avg       0.75      0.67      0.70      1187
#
# Test ROC AUC: 0.699925280840977

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
X_train_t = torch.from_numpy(X_train).float().to(device)
y_train_t = torch.from_numpy(y_train).float().unsqueeze(1).to(device)
X_test_t  = torch.from_numpy(X_test).float().to(device)
y_test_t  = torch.from_numpy(y_test).float().unsqueeze(1).to(device)

# DataLoader
train_ds = TensorDataset(X_train_t, y_train_t)
train_dl = DataLoader(train_ds, batch_size=32, shuffle=True, drop_last=True)


class ShallowMLP(nn.Module):
    def __init__(self, input_dim, hidden_dim=256, dropout=0.5):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.BatchNorm1d(hidden_dim),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_dim, 1),
            nn.Sigmoid()
        )
    def forward(self, x):
        return self.net(x)

model = ShallowMLP(input_dim=X_top.shape[1]).to(device)

optimizer = torch.optim.AdamW(model.parameters(), lr=1e-3, weight_decay=1e-5)
criterion = nn.BCELoss()

# 4) Training loop
n_epochs = 50
for epoch in range(1, n_epochs+1):
    model.train()
    total_loss = 0.0
    for xb, yb in train_dl:
        pred = model(xb)
        loss = criterion(pred, yb)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * xb.size(0)
    avg_loss = total_loss / len(train_dl.dataset)
    print(f"Epoch {epoch:2d}: train loss = {avg_loss:.4f}")

# 5) Evaluation
model.eval()
with torch.no_grad():
    y_prob = model(X_test_t).cpu().numpy().flatten()
    y_pred = (y_prob >= 0.5).astype(int)

print("\nClassification Report:")
print(classification_report(y_test, y_pred))
print("Test ROC AUC:", roc_auc_score(y_test, y_prob))
# Out:
# Epoch  1: train loss = 0.5063
# Epoch  2: train loss = 0.4638
# Epoch  3: train loss = 0.4405
# Epoch  4: train loss = 0.4231
# Epoch  5: train loss = 0.4129
# Epoch  6: train loss = 0.3968
# Epoch  7: train loss = 0.3788
# Epoch  8: train loss = 0.3615
# Epoch  9: train loss = 0.3524
# Epoch 10: train loss = 0.3356
# Epoch 11: train loss = 0.3155
# Epoch 12: train loss = 0.3109
# Epoch 13: train loss = 0.2932
# Epoch 14: train loss = 0.2752
# Epoch 15: train loss = 0.2571
# Epoch 16: train loss = 0.2478
# Epoch 17: train loss = 0.2299
# Epoch 18: train loss = 0.2304
# Epoch 19: train loss = 0.2088
# Epoch 20: train loss = 0.1959
# Epoch 21: train loss = 0.1965
# Epoch 22: train loss = 0.1854
# Epoch 23: train loss = 0.1789
# Epoch 24: train loss = 0.1545
# Epoch 25: train loss = 0.1550
# Epoch 26: train loss = 0.1547
# Epoch 27: train loss = 0.1497
# Epoch 28: train loss = 0.1436
# Epoch 29: train loss = 0.1326
# Epoch 30: train loss = 0.1396
# Epoch 31: train loss = 0.1207
# Epoch 32: train loss = 0.1241
# Epoch 33: train loss = 0.1290
# Epoch 34: train loss = 0.1114
# Epoch 35: train loss = 0.1109
# Epoch 36: train loss = 0.0995
# Epoch 37: train loss = 0.1051
# Epoch 38: train loss = 0.1034
# Epoch 39: train loss = 0.1102
# Epoch 40: train loss = 0.0927
# Epoch 41: train loss = 0.0954
# Epoch 42: train loss = 0.0980
# Epoch 43: train loss = 0.0883
# Epoch 44: train loss = 0.0830
# Epoch 45: train loss = 0.0869
# Epoch 46: train loss = 0.0829
# Epoch 47: train loss = 0.0761
# Epoch 48: train loss = 0.0820
# Epoch 49: train loss = 0.0747
# Epoch 50: train loss = 0.0822
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.40      0.35      0.38       248
#            1       0.83      0.86      0.85       939
#
#     accuracy                           0.76      1187
#    macro avg       0.62      0.61      0.61      1187
# weighted avg       0.74      0.76      0.75      1187
#
# Test ROC AUC: 0.6875193239204369
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
